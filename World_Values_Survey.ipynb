# %%
import pandas as pd

# %%
df = pd.read_csv("data_external/F00011931-WVS_TimeSeries_1981_2022_Csv_v3_0.zip", low_memory=False, compression="zip", sep=";")
df.head()
# Out:
# C:\Users\cnava\AppData\Local\Temp\ipykernel_40484\1787924275.py:1: DtypeWarning: Columns (12,13,19,20,545,945,946,959,991,1021,1023,1024,1025,1029,1030,1031,1035) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data_external/F00011931-WVS_TimeSeries_1981_2022_Csv_v3_0.zip", compression="zip", sep=";")
#               version                        doi  S002VS  S003 COUNTRY_ALPHA  \
# 0  3-0-0 (2022-03-14)  doi.org/10.14281/18241.17       3     8           ALB
# 1  3-0-0 (2022-03-14)  doi.org/10.14281/18241.17       3     8           ALB
# 2  3-0-0 (2022-03-14)  doi.org/10.14281/18241.17       3     8           ALB
# 3  3-0-0 (2022-03-14)  doi.org/10.14281/18241.17       3     8           ALB
# 4  3-0-0 (2022-03-14)  doi.org/10.14281/18241.17       3     8           ALB
#
#    COW_NUM COW_ALPHA  S006      S007  S008  ...  Y021C  Y022A Y022B Y022C  \
# 0      339       ALB     1  80320001    -4  ...      0      0   ,66     1
# ...

# %%
df.shape
# Out:
# (440055, 1041)

# %%
df[["S020", "E023"]]
# Out:
#         S020  E023
# 0       1998     4
# 1       1998     3
# 2       1998     4
# 3       1998     2
# 4       1998     4
# ...      ...   ...
# 440050  2020     2
# 440051  2020     2
# 440052  2020     2
# 440053  2020     2
# 440054  2020     2
#
# [440055 rows x 2 columns]
