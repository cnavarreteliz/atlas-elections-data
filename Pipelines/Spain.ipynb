# %%
from zipfile import ZipFile
import os
import pandas as pd

os.chdir("../")

# %%
country = "Spain"
month = 11
year = 2019
election_type = "general"

# %%
output = []
path = f"data/{country}/{year}{month}.zip"
for i in ZipFile(path).namelist():
    print(i)
    if i[-3:] == "DAT":
        tmp = pd.read_csv(ZipFile(path).open("09021911.DAT"), error_bad_lines=False, header=None, encoding="latin-1")
        output.append(tmp)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\cnava\Repos\paper-geography-elections\Pipelines\Spain.ipynb Cell 3 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/cnava/Repos/paper-geography-elections/Pipelines/Spain.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> output = []
#       <a href='vscode-notebook-cell:/c%3A/Users/cnava/Repos/paper-geography-elections/Pipelines/Spain.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> path = f"data/{country}/{year}{month}.zip"
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cnava/Repos/paper-geography-elections/Pipelines/Spain.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> for i in ZipFile(path).namelist():
#       <a href='vscode-notebook-cell:/c%3A/Users/cnava/Repos/paper-geography-elections/Pipelines/Spain.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a>     print(i)
#       <a href='vscode-notebook-cell:/c%3A/Users/cnava/Repos/paper-geography-elections/Pipelines/Spain.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a>     if i[-3:] == "DAT":
#
# File c:\Python310\lib\zipfile.py:1249, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1247 while True:
#    1248     try:
# -> 1249         self.fp = io.open(file, filemode)
#    1250     except OSError:
#    1251         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Spain/201911.zip'

# %%
pd.read_csv(ZipFile(path).open("04021911.DAT"), error_bad_lines=False, header=None, encoding="latin-1")
# Out:
# C:\Users\cnava\AppData\Local\Temp\ipykernel_42144\2089367733.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   pd.read_csv(ZipFile(path).open("04021911.DAT"), error_bad_lines=False, header=None, encoding="latin-1")
#                                                       0
# 0     022019111179999000031003TLaia                 ...
# 1     022019111179999000031004TEduard               ...
# 2     022019111179999000031005TXènia                ...
# 3     022019111179999000031006TDavid                ...
# 4     022019111179999000040001TAndrés               ...
# ...                                                 ...
# 4467  022019111439999000096005TJaume                ...
# 4468  022019111439999000096006TAdrià                ...
# 4469  022019111439999000101001TRut                  ...
# 4470  022019111439999000101002TGerard               ...
# 4471  022019111439999000101003TRafael               ...
#
# [4472 rows x 1 columns]

# %%
[(1, 2, "election_type"), (3, 6, "year"), (7, 8, "month"), (9, 9, "n_round"),
(10, 11, "region_id"), (12, 13, "province_id"), (14, 16, "commune_id"), (17, 18, "district_commune_id"),
(19, 22, "section_id"), (23, 23, "polling_code"), (24, 30, "ine_census"), (31, 37, "census_cera"), (38, 44, "census_cere"),
(45, 51, "total_cere"), (52, 58, "voters_first"), (59, 65, "voters_second"), (66, 72, "blank_votes"), (73, 79, "null_votes"),
(80, 86, "votes"), (87, 93, "favour_votes"), (94, 100, "negative_votes"), (101, 101, "official_data")]
# Out:
# [(1, 2, 'election_type'),
#  (3, 6, 'year'),
#  (7, 8, 'month'),
#  (9, 9, 'n_round'),
#  (10, 11, 'region_id'),
#  (12, 13, 'province_id'),
#  (14, 16, 'commune_id'),
#  (17, 18, 'district_commune_id'),
#  (19, 22, 'section_id'),
#  (23, 23, 'polling_code'),
#  (24, 30, 'ine_census'),
#  (31, 37, 'census_cera'),
#  (38, 44, 'census_cere'),
#  (45, 51, 'total_cere'),
#  (52, 58, 'voters_first'),
#  (59, 65, 'voters_second'),
#  (66, 72, 'blank_votes'),
#  (73, 79, 'null_votes'),
#  (80, 86, 'votes'),
#  (87, 93, 'favour_votes'),
#  (94, 100, 'negative_votes'),
#  (101, 101, 'official_data')]

# %%
pd.read_csv(ZipFile(path).open("09021911.DAT"), header=None)
# Out:
#                                                        0
# 0      022019111010400302001 B00004460000446000000000...
# 1      022019111010400602001 A00008420000842000000000...
# 2      022019111010400604001 B00004540000454000000000...
# 3      022019111010401303008 U00006620000662000000000...
# 4      022019111010401304006 U00006660000666000000000...
# ...                                                  ...
# 59622  022019111195200107002 B00005280000528000000000...
# 59623  022019111195200107003 B00006190000619000000000...
# 59624  022019111195200107006 A00006150000615000000000...
# 59625  022019111195200107006 B00006990000699000000000...
# 59626  022019111195200108009 B00008150000815000000000...
#
# [59627 rows x 1 columns]

# %%
df = pd.concat(output, ignore_index=True)

# %%
columns = [(1, 2, "election_type"), (3, 6, "year"), (7, 8, "month"), (9, 9, "n_round"),
(10, 11, "state_id"), (12, 13, "province_id"), (14, 16, "commune_id"), (17, 18, "district_commune_id"),
(19, 22, "section_id"), (23, 23, "polling_code"), (24, 29, "candidate_id"), (30, 36, "value")]

df = pd.read_csv(ZipFile(path).open("10021911.DAT"), header=None)

for column in columns:
    df[column[2]] = df[0].str[column[0] - 1:column[1]]
    
df["polling_id"] = df["state_id"] + df["province_id"] + df["commune_id"] + df["district_commune_id"] + df["section_id"] + df["polling_code"]
df[["candidate_id", "value"]] = df[["candidate_id", "value"]].astype(int)
df.head()
# Out:
#                                       0 election_type  year month n_round  \
# 0  022019111010400101001 B0000980000000            02  2019    11       1
# 1  022019111010400201001 B0000980000000            02  2019    11       1
# 2  022019111010400301001 U0000580000000            02  2019    11       1
# 3  022019111010400301002 A0000090000002            02  2019    11       1
# 4  022019111010400301003 A0000090000000            02  2019    11       1
#
#   state_id province_id commune_id district_commune_id section_id polling_code  \
# 0       01          04        001                  01       001             B
# 1       01          04        002                  01       001             B
# 2       01          04        003                  01       001             U
# 3       01          04        003                  01       002             A
# 4       01          04        003                  01       003             A
#
#    candidate_id  value      polling_id
# 0            98      0  010400101001 B
# 1            98      0  010400201001 B
# 2            58      0  010400301001 U
# 3             9      2  010400301002 A
# 4             9      0  010400301003 A

# %%
columns = [(1, 2, "election_type"), (3, 6, "year"), (7, 8, "month"), (9, 14, "candidate_id"),
(15, 64, "candidate"), (65, 214, "candidate_description"), (215, 220, "candidate_code_province"), 
(221, 226, "candidate_code_state"), (227, 232, "candidate_code_country")]

df_candidates = pd.read_csv(ZipFile(path).open("03021911.DAT"), encoding="latin-1", header=None)

for column in columns:
    df_candidates[column[2]] = df_candidates[0].str[column[0] - 1:column[1]]

df_candidates[["candidate_id"]] = df_candidates[["candidate_id"]].astype(int)
df_candidates["candidate"] = df_candidates["candidate"].str.strip()
df_candidates["candidate_description"] = df_candidates["candidate_description"].str.strip()

df_candidates.head()
# Out:
#                                                    0 election_type  year  \
# 0  02201911000002AHORA CANARIAS                  ...            02  2019
# 1  02201911000003ANDECHA                         ...            02  2019
# 2  02201911000005AUNACV                          ...            02  2019
# 3  02201911000006AVANT ADELANTE LOS VERDES       ...            02  2019
# 4  02201911000007AVANT ADELANTE LOS VERDES       ...            02  2019
#
#   month  candidate_id                  candidate  \
# 0    11             2             AHORA CANARIAS
# 1    11             3                    ANDECHA
# 2    11             5                     AUNACV
# 3    11             6  AVANT ADELANTE LOS VERDES
# 4    11             7  AVANT ADELANTE LOS VERDES
#
#                                candidate_description candidate_code_province  \
# 0  AHORA CANARIAS: Alternativa Nacionalista Canar...                  000002
# 1                                      ANDECHA ASTUR                  000003
# 2                          AUNA COMUNITAT VALENCIANA                  000005
# 3                          AVANT ADELANTE LOS VERDES                  000006
# 4                  LOS VERDES ECOPACIFISTAS ADELANTE                  000007
#
#   candidate_code_state candidate_code_country
# 0               000002                 000002
# 1               000003                 000003
# 2               000005                 000005
# 3               000006                 000006
# 4               000006                 000006

# %%
df_candidates[["candidate_id", "candidate"]].tail(50)
# Out:
#      candidate_id                 candidate
# 56             63                      PCTC
# 57             64                      PCTE
# 58             65                 PCTE/ELAK
# 59             66                 PCTE/ELAK
# 60             67                      PCTG
# 61             68                     PDSJE
# 62             72                        PH
# 63             73                     P-LIB
# 64             74                PODEMOS-EU
# 65             75              PODEMOS-EUIB
# 66             76              PODEMOS-EUPV
# 67             77                PODEMOS-IU
# 68             78                PODEMOS-IU
# 69             79               PODEMOS-IU-
# 70             80       PODEMOS-IU-BATZARRE
# 71             81          PODEMOS-IU LV CA
# 72             82                PODEMOS-IX
# 73             83                        PP
# 74             84                        PP
# 75             85                        PP
# 76             86                   PP-FORO
# 77             87                      PPSO
# 78             88                       PRC
# 79             89                    PREPAL
# 80             90                  PSC-PSOE
# 81             91                PSdeG-PSOE
# 82             92             PSE-EE (PSOE)
# 83             93                      PSOE
# 84             94                      PSOE
# 85             95                     PUM+J
# 86             96                     PUM+J
# 87             97                     PUM+J
# 88             98                     PUM+J
# 89             99                     PUM+J
# 90            100                      PYLN
# 91            101          RECORTES CERO-GV
# 92            102  RECORTES CERO-GV-PCAS-TC
# 93            103                      RISA
# 94            105                 SOLIDARIA
# 95            106               SOMOS REGIÓ
# 96            108               ¡TERUEL EXI
# 97            109                       UDT
# 98            110            UIG-SOM-CUIDES
# 99            111               UNIDOS SÍ-A
# 100           112               UNIÓN REGIO
# 101           113                       UPL
# 102           114                    VERDES
# 103           115                LOS VERDES
# 104           116                       VOX
# 105           117                       XAV

# %%
df = pd.merge(df, df_candidates[["candidate_id", "candidate"]], on="candidate_id")
df["state_id"] = df["state_id"].astype(int)
df.head()
# Out:
#                                       0 election_type  year month n_round  \
# 0  022019111010400101001 B0000980000000            02  2019    11       1
# 1  022019111010400201001 B0000980000000            02  2019    11       1
# 2  022019111010400303003 C0000980000000            02  2019    11       1
# 3  022019111010400602001 A0000980000000            02  2019    11       1
# 4  022019111010401101002 A0000980000000            02  2019    11       1
#
#    state_id province_id commune_id district_commune_id section_id  \
# 0         1          04        001                  01       001
# 1         1          04        002                  01       001
# 2         1          04        003                  03       003
# 3         1          04        006                  02       001
# 4         1          04        011                  01       002
#
#   polling_code  candidate_id  value      polling_id  \
# 0            B            98      0  010400101001 B
# 1            B            98      0  010400201001 B
# 2            C            98      0  010400303003 C
# 3            A            98      0  010400602001 A
# 4            A            98      0  010401101002 A
#
#                                          candidate_x candidate_y
# 0  PUM+J                                         ...       PUM+J
# 1  PUM+J                                         ...       PUM+J
# 2  PUM+J                                         ...       PUM+J
# 3  PUM+J                                         ...       PUM+J
# 4  PUM+J                                         ...       PUM+J

# %%
df.state_id.unique()
# Out:
# array([ 1,  2,  3,  4,  5,  6,  7,  8, 10, 12, 15, 16, 17, 18, 19, 99,  9,
#        11, 13, 14])

# %%
df_filtered = df[["candidate", "value", "polling_id"]].copy()
df_filtered["rank"] = df_filtered.groupby(["polling_id"])["value"].rank("min", ascending=False).astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\cnava\Repos\paper-geography-elections\Pipelines\Spain.ipynb Cell 13 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cnava/Repos/paper-geography-elections/Pipelines/Spain.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> df_filtered = df[["candidate", "value", "polling_id"]].copy()
#       <a href='vscode-notebook-cell:/c%3A/Users/cnava/Repos/paper-geography-elections/Pipelines/Spain.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> df_filtered["rank"] = df_filtered.groupby(["polling_id"])["value"].rank("min", ascending=False).astype(int)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:3810, in DataFrame.__getitem__(self, key)
#    3808     if is_iterator(key):
#    3809         key = list(key)
# -> 3810     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3812 # take() does not accept boolean indexers
#    3813 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:6111, in Index._get_indexer_strict(self, key, axis_name)
#    6108 else:
#    6109     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6111 self._raise_if_missing(keyarr, indexer, axis_name)
#    6113 keyarr = self.take(indexer)
#    6114 if isinstance(key, Index):
#    6115     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:6174, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6171     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6173 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6174 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['candidate'] not in index"

# %%
df.candidate.unique()
# Out:
# array(['PUM+J                                             ',
#        'PCPA                                              ',
#        'AxSÍ                                              ',
#        'PACMA                                             ',
#        'VOX                                               ',
#        'RECORTES CERO-GV                                  ',
#        'Cs                                                ',
#        'PODEMOS-IU LV CA                                  ',
#        'EB                                                ',
#        'PSOE                                              ',
#        'PP                                                ',
#        'PCOE                                              ',
#        'MÁS PAÍS-AN                                       ',
#        'PCTE                                              ',
#        'IZAR                                              ',
#        'CAnda                                             ',
#        'RISA                                              ',
#        'PYLN                                              ',
#        'PCPE                                              ',
#        'FIA                                               ',
#        'CHA                                               ',
#        'PODEMOS-IU-                                       ',
#        'AUNACV                                            ',
#        'PODEMOS-IU                                        ',
#        '¡TERUEL EXI                                       ',
#        'UDT                                               ',
#        'M PAÍS-CHA-                                       ',
#        'MAS                                               ',
#        'PP-FORO                                           ',
#        'PH                                                ',
#        'MÁS PAÍS-EQ                                       ',
#        'PODEMOS-IX                                        ',
#        'ANDECHA                                           ',
#        'PODEMOS-EUIB                                      ',
#        'MÉS-ESQUERR                                       ',
#        'M PAÍS                                            ',
#        'P-LIB                                             ',
#        'CONTIGO                                           ',
#        'PDSJE                                             ',
#        'AHORA CANARIAS                                    ',
#        'VERDES                                            ',
#        'PCPC                                              ',
#        'NC-CCa-PNC                                        ',
#        'CCa-PNC-NC                                        ',
#        'PRC                                               ',
#        'RECORTES CERO-GV-PCAS-TC                          ',
#        'FE de las J                                       ',
#        'XAV                                               ',
#        'PREPAL                                            ',
#        'UPL                                               ',
#        'centrados                                         ',
#        'PPSO                                              ',
#        'UNIÓN REGIO                                       ',
#        'MÁS PAÍS                                          ',
#        'IZQP                                              ',
#        'JxCAT-JUNTS                                       ',
#        'ECP-GUANYEM                                       ',
#        'PCTC                                              ',
#        'PSC-PSOE                                          ',
#        'CUP-PR                                            ',
#        'I.Fem                                             ',
#        'ERC-SOBIRANISTES                                  ',
#        'EXTREMADURA UNIDA                                 ',
#        'PCTG                                              ',
#        'PODEMOS-EU                                        ',
#        'BNG                                               ',
#        'PSdeG-PSOE                                        ',
#        'C 21                                              ',
#        'NA+                                               ',
#        'PCTE/ELAK                                         ',
#        'GBAI                                              ',
#        'EH Bildu                                          ',
#        'PODEMOS-IU-BATZARRE                               ',
#        'EAJ-PNV                                           ',
#        'PSE-EE (PSOE)                                     ',
#        'ELAK/PCTE                                         ',
#        'SOLIDARIA                                         ',
#        'MÁS PAÍS-CA                                       ',
#        'DPL                                               ',
#        'SOMOS REGIÓ                                       ',
#        'MÉS COMPROM                                       ',
#        'ERPV                                              ',
#        'PODEMOS-EUPV                                      ',
#        'AVANT ADELANTE LOS VERDES                         ',
#        'AVANT LOS VERDES                                  ',
#        'UIG-SOM-CUIDES                                    ',
#        'UNIDOS SÍ-A                                       ',
#        'MDyC                                              ',
#        'LOS VERDES                                        ',
#        'CpM                                               '], dtype=object)

# %%
df_filtered = df_filtered.groupby(["polling_id", "candidate"]).agg({"value": "sum"})
df_filtered["rate"] = df_filtered.groupby(level=[0], group_keys=False).apply(lambda x: x/x.sum())
df_filtered = df_filtered.reset_index()
df_filtered = df_filtered[["polling_id", "candidate", "rate", "value"]]

# %%
df_nuts = pd.read_csv("data/Spain/nuts_2_equivalences.csv")
df_nuts["nuts_1"] = df_nuts["nuts_2"].str[0:3]
df_nuts.head()
# Out:
#    state_id nuts_2 province_name nuts_1
# 0         1   ES61     Andalucía    ES6
# 1         2   ES24        Aragón    ES2
# 2         3   ES12      Asturias    ES1
# 3         4   ES53      Baleares    ES5
# 4         5   ES70      Canarias    ES7

# %%
df_filtered.to_csv(f"data_output/Spain/{year}_{election_type}.csv.gz", compression="gzip", index=False)

# %%
df_location = df[["polling_id", "state_id", "province_id", "commune_id", "district_commune_id"]]
df_location = pd.merge(df_location, df_nuts, how="left", on="state_id")
df_location.to_csv(f"data_output/Spain/{year}_{election_type}_location.csv.gz", compression="gzip", index=False)
