# %%
import pandas as pd

pd.options.display.max_columns = None

# %%
year = 2011

df = pd.read_csv(f"../data/Switzerland/{year}.csv")
df["candidate"] = df["candidate_first_name"] + " " + df["candidate_family_name"]
df = df.rename(columns={
  "candidate_votes": "value",
  "list_name": "party_id",
  "entity_district": "district_id",
})
df = df[["candidate", "value", "party_id", "district_id"]]
df.head()
# Out:
#           candidate  value                         party_id district_id
# 0        Marc Bürgi    161  Bürgerlich Demokratische Partei   Arlesheim
# 1  Esther Meisinger    146  Bürgerlich Demokratische Partei   Arlesheim
# 2   Peter H. Müller    281  Bürgerlich Demokratische Partei   Arlesheim
# 3     Hanspeter Ryf    188  Bürgerlich Demokratische Partei   Arlesheim
# 4       Peter Staub    169  Bürgerlich Demokratische Partei   Arlesheim

# %%
election_type = "camera"

df.to_csv(f"../data_output/Switzerland/{year}_{election_type}_district.csv.gz", index=False, compression="gzip")

df.head()
# Out:
#           candidate  value                         party_id district_id
# 0        Marc Bürgi    161  Bürgerlich Demokratische Partei   Arlesheim
# 1  Esther Meisinger    146  Bürgerlich Demokratische Partei   Arlesheim
# 2   Peter H. Müller    281  Bürgerlich Demokratische Partei   Arlesheim
# 3     Hanspeter Ryf    188  Bürgerlich Demokratische Partei   Arlesheim
# 4       Peter Staub    169  Bürgerlich Demokratische Partei   Arlesheim
