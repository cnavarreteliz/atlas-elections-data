# %%
import pandas as pd

# %%
storage_options = {"User-Agent": "Mozilla/5.0"}

df = pd.read_excel("http://tilastokeskus.fi/tk/he/vaalit/vaalit99/ehdokas.xls", header=3, storage_options=storage_options)
df.head()
# Out:
#                               Unnamed: 0 Unnamed: 1     Unnamed: 2
# 0  VAALIPIIRI, PUOLUE JA EHDOKAS          ÄÄNIMÄÄRÄ    VERTAUSLUKU
# 1   VALKRETS, PARTI OCH KANDIDAT           RÖSTETAL  JÄMFÖRELSETAL
# 2  CONSTITUENCY, PARTY AND CANDIDATE      NUMBER OF     COMPARISON
# 3                                    NaN      VOTES         FIGURE
# 4                 HELSINKI - HELSINGFORS        NaN            NaN

# %%
df.head(50)
# Out:
#                                    Unnamed: 0  Unnamed: 1  \
# 0               VAALIPIIRI, PUOLUE JA EHDOKAS   ÄÄNIMÄÄRÄ
# 1         VALKRETS, PARTI OCH KANDIDAT          RÖSTETAL
# 2       CONSTITUENCY, PARTY AND CANDIDATE       NUMBER OF
# 3                                         NaN   VOTES
# 4
# 5      HELSINGIN KAUPUNGIN -
# 6      HELSINGFORS STADS
# 7
# 8     SUOMEN KESKUSTA - CENTERN I FINLAND -
# 9     CENTER PARTY OF FINLAND
# 10     Molander Sole                                 2691
# 11     Tilev Kukka-Maaria                            1929
# 12     Pajunen Aimo                                  1533
# 13     Paasikivi Annukka                             1090
# 14     Pentti Veikko                                  493
# 15     Apajalahti Jouni                               472
# 16     Tikkanen Riina                                 459
# 17     Antinmäki-Vesterinen Riitta                    353
# 18     Vennamo Meri                                   351
# ...
