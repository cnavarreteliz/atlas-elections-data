# %%
import numpy as np
import pandas as pd
import os

os.chdir("../../")
pd.set_option("display.max_columns", None)

# %%
df = pd.read_excel(f"data/France/Congress/2019.xlsx")
df = df.reset_index()
df.head()
# Out:
#    index Code du département Libellé du département  \
# 0      0                  01                    Ain
# 1      1                  01                    Ain
# 2      2                  01                    Ain
# 3      3                  01                    Ain
# 4      4                  01                    Ain
#
#    Code de la circonscription Libellé de la circonscription  \
# 0                           4          4ème circonscription
# 1                           5          5ème circonscription
# 2                           5          5ème circonscription
# 3                           5          5ème circonscription
# 4                           5          5ème circonscription
#
#    Code de la commune    Libellé de la commune Code du b.vote  Inscrits  \
# 0                   1  L'Abergement-Clémenciat           0001       644
# 1                   2    L'Abergement-de-Varey           0001       218
# ...
