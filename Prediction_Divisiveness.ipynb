# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# C:\Users\cnavarreteliz\AppData\Roaming\Python\Python39\site-packages\geopandas\_compat.py:112: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.3-CAPI-1.16.1). Conversions between both will be slow.
#   warnings.warn(

# %%
year = 2021
country = "Chile"
location_level = "commune"

# %%
df_location = pd.read_csv(f"data_output/{country}/{year}_first_round_location.csv.gzip", compression="gzip")
df_location = df_location.rename(columns={"electors": "voters"})
df_location.head()
# Out:
#                                           polling_id  region_id       region  \
# 0  ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...          1  DE TARAPACA
# 1  ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...          1  DE TARAPACA
# 2  ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...          1  DE TARAPACA
# 3  ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...          1  DE TARAPACA
# 4  ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...          1  DE TARAPACA
#
#   province  senate_district  district        commune electoral_circ  \
# 0  IQUIQUE                2         2  ALTO HOSPICIO  ALTO HOSPICIO
# 1  IQUIQUE                2         2  ALTO HOSPICIO  ALTO HOSPICIO
# 2  IQUIQUE                2         2  ALTO HOSPICIO  ALTO HOSPICIO
# 3  IQUIQUE                2         2  ALTO HOSPICIO  ALTO HOSPICIO
# 4  IQUIQUE                2         2  ALTO HOSPICIO  ALTO HOSPICIO
#
#                              polling_place  polling_table polling_type  \
# 0  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             20            M
# 1  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             21            M
# 2  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             22            M
# 3  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             23            M
# 4  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             24            M
#
#   mixed_polling  voters
# 0           20M     333
# 1           21M     340
# 2           22M     341
# 3           23M     344
# 4           24M     342

# %%
df = pd.read_csv(f"data_output/{country}/{year}_first_round.csv.gzip", compression="gzip")
df.columns = [x.lower() for x in df.columns]
df = pd.merge(df, df_location, on="polling_id")
df.head()
# Out:
#                                           polling_id  \
# 0  ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...
# 1  ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...
# 2  ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...
# 3  ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...
# 4  ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...
#
#                   candidate  value  rank      rate  region_id       region  \
# 0        GABRIEL BORIC FONT   22.0     3  0.134969          1  DE TARAPACA
# 1    JOSE ANTONIO KAST RIST   36.0     2  0.220859          1  DE TARAPACA
# 2  YASNA PROVOSTE CAMPILLAY   15.0     5  0.092025          1  DE TARAPACA
# 3  SEBASTIAN SICHEL RAMIREZ   12.0     6  0.073620          1  DE TARAPACA
# 4   EDUARDO ARTES BRICHETTI    1.0     7  0.006135          1  DE TARAPACA
#
#   province  senate_district  district        commune electoral_circ  \
# 0  IQUIQUE                2         2  ALTO HOSPICIO  ALTO HOSPICIO
# 1  IQUIQUE                2         2  ALTO HOSPICIO  ALTO HOSPICIO
# 2  IQUIQUE                2         2  ALTO HOSPICIO  ALTO HOSPICIO
# 3  IQUIQUE                2         2  ALTO HOSPICIO  ALTO HOSPICIO
# 4  IQUIQUE                2         2  ALTO HOSPICIO  ALTO HOSPICIO
#
#                              polling_place  polling_table polling_type  \
# 0  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             20            M
# 1  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             20            M
# 2  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             20            M
# 3  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             20            M
# 4  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             20            M
#
#   mixed_polling  voters
# 0           20M     333
# 1           20M     333
# 2           20M     333
# 3           20M     333
# 4           20M     333

# %%
df_runoff = pd.read_csv(f"data_output/{country}/{year}_runoff.csv.gzip", compression="gzip")
df_runoff.columns = [x.lower() for x in df_runoff.columns]
df_runoff = pd.merge(df_runoff, df_location, on="polling_id")

df_runoff.head()
# Out:
#                                           polling_id               candidate  \
# 0  ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...      GABRIEL BORIC FONT
# 1  ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...  JOSE ANTONIO KAST RIST
# 2  ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...      GABRIEL BORIC FONT
# 3  ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...  JOSE ANTONIO KAST RIST
# 4  ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...      GABRIEL BORIC FONT
#
#    value  rank      rate  region_id       region province  senate_district  \
# 0   71.0     2  0.435583          1  DE TARAPACA  IQUIQUE                2
# 1   92.0     1  0.564417          1  DE TARAPACA  IQUIQUE                2
# 2   82.0     1  0.503067          1  DE TARAPACA  IQUIQUE                2
# 3   81.0     2  0.496933          1  DE TARAPACA  IQUIQUE                2
# 4   81.0     1  0.540000          1  DE TARAPACA  IQUIQUE                2
#
#    district        commune electoral_circ  \
# 0         2  ALTO HOSPICIO  ALTO HOSPICIO
# 1         2  ALTO HOSPICIO  ALTO HOSPICIO
# 2         2  ALTO HOSPICIO  ALTO HOSPICIO
# 3         2  ALTO HOSPICIO  ALTO HOSPICIO
# 4         2  ALTO HOSPICIO  ALTO HOSPICIO
#
#                              polling_place  polling_table polling_type  \
# 0  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             20            M
# 1  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             20            M
# 2  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             21            M
# 3  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             21            M
# 4  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             22            M
#
#   mixed_polling  voters
# 0           20M     333
# 1           20M     333
# 2           21M     340
# 3           21M     340
# 4           22M     341

# %%
df_dv = pd.read_csv(f"data_output/{country}/{year}_divisiveness_{location_level}.csv.gzip", compression="gzip")
df_dv = df_dv.rename(columns={"alternative": "candidate"})

df_dv.head()
# Out:
#      commune                       candidate     value
# 0  ALGARROBO         FRANCO PARISI FERNANDEZ  0.025077
# 1  ALGARROBO              GABRIEL BORIC FONT  0.052863
# 2  ALGARROBO          JOSE ANTONIO KAST RIST  0.041479
# 3  ALGARROBO  MARCO ENRIQUEZ-OMINAMI GUMUCIO  0.017745
# 4  ALGARROBO        SEBASTIAN SICHEL RAMIREZ  0.031024

# %%
# gdf = gpd.read_file("https://raw.githubusercontent.com/fcortes/Chile-GeoJSON/master/comunas.geojson")

# gdf["Comuna"] = gdf["Comuna"].apply(lambda x: x.upper())
# for a, b in [("Á", "A"), ("É", "E"), ("Í", "I"), ("Ó", "O"), ("Ú", "U"), ("Ü", "U")]:
#     gdf["Comuna"] = gdf["Comuna"].str.replace(a, b)

# gdf["Comuna"] = gdf["Comuna"].astype(str)
# gdf["Comuna"] = gdf["Comuna"].replace({
#     "TREGUACO": "TREHUACO",
#     "MARCHIHUE": "MARCHIGUE",
#     "PAIHUANO": "PAIGUANO",
#     "O'HIGGINS": "O'HIGGINS",
#     "CABO DE HORNOS": "CABO DE HORNOS(EX-NAVARINO)"
# })

# gdf = gdf.rename(columns={"Comuna": "commune"})

# gdf.head()

# %%
# df_tmp = pd.merge(df_runoff, df_location, on="polling_id")
# df_tmp = df_tmp.groupby(["commune", "candidate"]).agg({"value": "sum"})
# df_tmp["rate"] = df_tmp.groupby(level=[0]).apply(lambda x: x/x.sum())
# df_tmp = df_tmp.reset_index()
# df_tmp.head()

# %%
# dd = df_runoff.copy() #.groupby("commune").agg({"value": "mean"}).reset_index()
# dd = pd.merge(gdf, dd, on=location_level)
# dd["rank"] = dd.groupby(location_level)["value"].rank(ascending=False).astype(int)

# dd = dd[dd["rank"] == 1]

# fig, ax = plt.subplots(figsize=(10, 10), dpi=120)
# dd[~dd[location_level].isin(["ISLA DE PASCUA"])]\
#     .plot(
#     column="candidate",
#     edgecolor="black",
#     cmap="tab10",
#     lw=0.1,
#     ax=ax,
#     legend=True,
#     legend_kwds=dict(
#         loc="upper right",
#         bbox_to_anchor=(0.5, .9),
#         fontsize="small",
#         title="",
#         frameon=False
#     )
# )

# legend_kwds={"shrink": 0.3}
# cb = ax.get_figure().get_axes()[1]
# cb.set_yticklabels(["{0:.0f}%".format(ytick*100) for ytick in cb.get_yticks()])

# plt.axis("off")

# %%
import statsmodels.api as sm

# %%
df_location
# Out:
#                                               polling_id  region_id  \
# 0      ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...          1
# 1      ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...          1
# 2      ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...          1
# 3      ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...          1
# 4      ALTO HOSPICIO-ALTO HOSPICIO-ANEXO DE COLEGIO S...          1
# ...                                                  ...        ...
# 46634             YUNGAY-YUNGAY-LICEO DE YUNGAY-17-M-17M         16
# 46635             YUNGAY-YUNGAY-LICEO DE YUNGAY-18-M-18M         16
# 46636             YUNGAY-YUNGAY-LICEO DE YUNGAY-19-M-19M         16
# 46637             YUNGAY-YUNGAY-LICEO DE YUNGAY-20-M-20M         16
# 46638             YUNGAY-YUNGAY-LICEO DE YUNGAY-21-M-21M         16
#
#             region   province  senate_district  district        commune  \
# 0      DE TARAPACA    IQUIQUE                2         2  ALTO HOSPICIO
# 1      DE TARAPACA    IQUIQUE                2         2  ALTO HOSPICIO
# 2      DE TARAPACA    IQUIQUE                2         2  ALTO HOSPICIO
# 3      DE TARAPACA    IQUIQUE                2         2  ALTO HOSPICIO
# 4      DE TARAPACA    IQUIQUE                2         2  ALTO HOSPICIO
# ...            ...        ...              ...       ...            ...
# 46634     DE ÑUBLE  DIGUILLIN               16        19         YUNGAY
# 46635     DE ÑUBLE  DIGUILLIN               16        19         YUNGAY
# 46636     DE ÑUBLE  DIGUILLIN               16        19         YUNGAY
# 46637     DE ÑUBLE  DIGUILLIN               16        19         YUNGAY
# 46638     DE ÑUBLE  DIGUILLIN               16        19         YUNGAY
#
#       electoral_circ                            polling_place  polling_table  \
# 0      ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             20
# 1      ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             21
# 2      ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             22
# 3      ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             23
# 4      ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA             24
# ...              ...                                      ...            ...
# 46634         YUNGAY                          LICEO DE YUNGAY             17
# 46635         YUNGAY                          LICEO DE YUNGAY             18
# 46636         YUNGAY                          LICEO DE YUNGAY             19
# 46637         YUNGAY                          LICEO DE YUNGAY             20
# 46638         YUNGAY                          LICEO DE YUNGAY             21
#
#       polling_type mixed_polling  voters
# 0                M           20M     333
# 1                M           21M     340
# 2                M           22M     341
# 3                M           23M     344
# 4                M           24M     342
# ...            ...           ...     ...
# 46634            M           17M     332
# 46635            M           18M     333
# 46636            M           19M     328
# 46637            M           20M     329
# 46638            M           21M     340
#
# [46639 rows x 13 columns]

# %%
df_voters = df_location.groupby(location_level).agg({"voters": "sum"}).reset_index()
df_voters.head()
# Out:
#            commune  voters
# 0        ALGARROBO   14805
# 1            ALHUE    6118
# 2      ALTO BIOBIO    5583
# 3  ALTO DEL CARMEN    5148
# 4    ALTO HOSPICIO   60343

# %%
df_tmp = df.groupby([location_level, "candidate"]).agg({"value": "sum"})
df_tmp["rate"] = df_tmp.groupby(level=[0]).apply(lambda x: x/x.sum())
df_tmp = df_tmp.reset_index()
df_tmp.head()
# Out:
#      commune                       candidate   value      rate
# 0  ALGARROBO         EDUARDO ARTES BRICHETTI    90.0  0.011038
# 1  ALGARROBO         FRANCO PARISI FERNANDEZ   568.0  0.069659
# 2  ALGARROBO              GABRIEL BORIC FONT  1978.0  0.242580
# 3  ALGARROBO          JOSE ANTONIO KAST RIST  2877.0  0.352833
# 4  ALGARROBO  MARCO ENRIQUEZ-OMINAMI GUMUCIO   472.0  0.057886

# %%
df_hhi = df_tmp.copy()
df_hhi["hhi"] = df_hhi["rate"] ** 2
df_hhi["entropy"] = df_hhi["rate"] * np.log(df_hhi["rate"])
df_hhi = df_hhi.groupby(location_level).agg({"hhi": "sum", "entropy": "sum"})
df_hhi["entropy"] = -1 * df_hhi["entropy"]
df_hhi = df_hhi.reset_index()
df_hhi.head()
# Out:
# C:\Python39\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#            commune       hhi   entropy
# 0        ALGARROBO  0.229193  1.639877
# 1            ALHUE  0.186300  1.758382
# 2      ALTO BIOBIO  0.192925  1.750439
# 3  ALTO DEL CARMEN  0.287311  1.485083
# 4    ALTO HOSPICIO  0.256063  1.578108

# %%
df_model = df_runoff.groupby([location_level, "candidate"]).agg({"value": "sum"})

df_model["rate"] = df_model.groupby(level=[0]).apply(lambda x: x/x.sum())

df_model = df_model.rename(columns={"value": "votes"}).reset_index()

df_model = pd.merge(df_model, df_dv.rename(columns={"value": "divisiveness"}), on=[location_level, "candidate"])

df_model = pd.merge(df_tmp, df_model, on=[location_level, "candidate"])

if country != "Romania":
    df_model = pd.merge(df_model, df_voters, on=location_level)

if country == "France":
    df_poverty = pd.read_excel("data_external/France/poverty_2017.xlsx", sheet_name="Figure 3", header=2).dropna()
    df_poverty["Taux de pauvreté"] = df_poverty["Taux de pauvreté"].astype(float) / 100
    df_poverty = df_poverty.rename(columns={"Code": "geo_id", "Département": "department", "Taux de pauvreté": "poverty_rate"})
    
elif country == "Chile":
    df_poverty = pd.read_excel("data_external/Chile/poverty_2020.xlsx", header=2)
    df_poverty = df_poverty[~df_poverty["Nombre comuna"].isna()]
    df_poverty = df_poverty.rename(columns={"Nombre comuna": "commune", "Porcentaje de personas en situación de pobreza por ingresos 2020": "poverty_rate"})
    df_poverty["commune"] = df_poverty["commune"].apply(lambda x: x.upper())

    for a, b in [("Á", "A"), ("É", "E"), ("Í", "I"), ("Ó", "O"), ("Ú", "U"), ("Ü", "U")]:
        df_poverty["commune"] = df_poverty["commune"].str.replace(a, b)
    df_poverty["commune"] = df_poverty["commune"].astype(str)
    df_poverty["commune"] = df_poverty["commune"].replace(
        {"TREGUACO": "TREHUACO", "MARCHIHUE": "MARCHIGUE", "PAIGUANO": "PAIHUANO", "O’HIGGINS": "O'HIGGINS", "CABO DE HORNOS": "CABO DE HORNOS(EX-NAVARINO)"})

    df_poverty = df_poverty[["commune", "poverty_rate"]]

if country in ["Chile", "France"]:
    df_model = pd.merge(df_model, df_poverty, on=location_level)
    
df_model = pd.merge(df_model, df_hhi, on=location_level)

df_model["growth"] = df_model["rate_y"] - df_model["rate_x"]

df_model = df_model.dropna()
df_model.to_csv(f"data_output/data_model_{country}_{year}.csv", index=False)

df_model
# Out:
#          commune               candidate    value    rate_x    votes  \
# 0      ALGARROBO      GABRIEL BORIC FONT   1978.0  0.242580   4580.0
# 1      ALGARROBO  JOSE ANTONIO KAST RIST   2877.0  0.352833   5096.0
# 2          ALHUE      GABRIEL BORIC FONT    636.0  0.256762   1952.0
# 3          ALHUE  JOSE ANTONIO KAST RIST    467.0  0.188535   1092.0
# 4    ALTO BIOBIO      GABRIEL BORIC FONT    377.0  0.204115   1283.0
# ..           ...                     ...      ...       ...      ...
# 683     ZAPALLAR  JOSE ANTONIO KAST RIST   1831.0  0.337823   3518.0
# 684       ÑIQUEN      GABRIEL BORIC FONT    531.0  0.114761   1791.0
# 685       ÑIQUEN  JOSE ANTONIO KAST RIST   2000.0  0.432246   3685.0
# 686        ÑUÑOA      GABRIEL BORIC FONT  48165.0  0.394297  81608.0
# 687        ÑUÑOA  JOSE ANTONIO KAST RIST  29426.0  0.240893  55389.0
#
#        rate_y  divisiveness  voters  poverty_rate       hhi   entropy  \
# 0    0.473336      0.052863   14805      0.096476  0.229193  1.639877
# 1    0.526664      0.041479   14805      0.096476  0.229193  1.639877
# 2    0.641261      0.045682    6118      0.071957  0.186300  1.758382
# 3    0.358739      0.035981    6118      0.071957  0.186300  1.758382
# 4    0.545493      0.048179    5583      0.289271  0.192925  1.750439
# ..        ...           ...     ...           ...       ...       ...
# 683  0.561712      0.045994    9155      0.086290  0.227922  1.627534
# 684  0.327064      0.028514   10758      0.191821  0.252866  1.609887
# 685  0.672936      0.039620   10758      0.191821  0.252866  1.609887
# 686  0.595692      0.058021  198985      0.039766  0.261585  1.527131
# 687  0.404308      0.043067  198985      0.039766  0.261585  1.527131
#
#        growth
# 0    0.230756
# 1    0.173831
# 2    0.384499
# 3    0.170204
# 4    0.341378
# ..        ...
# 683  0.223889
# 684  0.212302
# 685  0.240691
# 686  0.201395
# 687  0.163415
#
# [688 rows x 12 columns]

# %%
# gdf = gpd.read_file("https://raw.githubusercontent.com/fcortes/Chile-GeoJSON/master/comunas.geojson")

# gdf["Comuna"] = gdf["Comuna"].apply(lambda x: x.upper())
# for a, b in [("Á", "A"), ("É", "E"), ("Í", "I"), ("Ó", "O"), ("Ú", "U"), ("Ü", "U")]:
#     gdf["Comuna"] = gdf["Comuna"].str.replace(a, b)

# gdf["Comuna"] = gdf["Comuna"].astype(str)
# gdf["Comuna"] = gdf["Comuna"].replace({
#     "TREGUACO": "TREHUACO",
#     "MARCHIHUE": "MARCHIGUE",
#     "PAIHUANO": "PAIGUANO",
#     "O'HIGGINS": "O'HIGGINS",
#     "CABO DE HORNOS": "CABO DE HORNOS(EX-NAVARINO)"
# })

# gdf = gdf.rename(columns={"Comuna": "commune"})

# gdf.head()

# %%
location = "polling_id"

def get_rate(df, location=["polling_id"], level=[0]):
    df_tmp = df.groupby(location + ["candidate"]).agg({"value": "sum"}) # [~df["candidate"].isin(values)]
    df_tmp["rate"] = df_tmp.groupby(level=level).apply(lambda x: x/x.sum())
    df_tmp = df_tmp.reset_index()

    return df_tmp

df_a = get_rate(df, location=[location_level, "polling_id"], level=[0, 1])
df_a = pd.merge(df_a, df_dv.rename(columns={"value": "divisiveness"}), on=[location_level, "candidate"])

df_b = get_rate(df_runoff)

# %%
df_a.candidate.unique()
# Out:
# array(['FRANCO PARISI FERNANDEZ', 'GABRIEL BORIC FONT',
#        'JOSE ANTONIO KAST RIST', 'MARCO ENRIQUEZ-OMINAMI GUMUCIO',
#        'SEBASTIAN SICHEL RAMIREZ', 'YASNA PROVOSTE CAMPILLAY'],
#       dtype=object)

# %%
labels = {
    'Anne HIDALGO': "hidalgo",
    'Emmanuel MACRON': "macron",
    'Fabien ROUSSEL': "roussel",
    'Jean LASSALLE': "lassalle", 
    'Jean-Luc MÉLENCHON': "melenchon", 
    'Marine LE PEN': "le_pen",
    'Nathalie ARTHAUD': "arthaud", 
    'Nicolas DUPONT-AIGNAN': "dupont",
    'Philippe POUTOU': "poutou",
    'Valérie PÉCRESSE': "pecresse", 
    'Yannick JADOT': "jadot",
    'Éric ZEMMOUR': "zemmour",
    
    'ALVARO FERNANDES DIAS': "alvaro",
    'BENEVENUTO DACIOLO FONSECA DOS SANTOS': "daciolo",
    'CIRO FERREIRA GOMES': "ciro",
    'FERNANDO HADDAD': "haddad",
    'GERALDO JOSÉ RODRIGUES ALCKMIN FILHO': "alckmin",
    'GUILHERME CASTRO BOULOS': "boulos",
    'HENRIQUE DE CAMPOS MEIRELLES': "meirelles",
    'JAIR MESSIAS BOLSONARO': "bolsonaro",
    'JOSE MARIA EYMAEL': "eymael",
    'JOÃO DIONISIO FILGUEIRA BARRETO AMOEDO': "amoedo",
    'JOÃO VICENTE FONTELLA GOULART': "goulart",
    'MARIA OSMARINA MARINA DA SILVA VAZ DE LIMA': "da_silva",
    'VERA LUCIA PEREIRA DA SILVA SALGADO': "vera_lucia",
    
    'GABRIEL BORIC FONT': "boric",
    'JOSE ANTONIO KAST RIST': "kast",
    'YASNA PROVOSTE CAMPILLAY': "provoste",
    'SEBASTIAN SICHEL RAMIREZ': "sichel",
    'EDUARDO ARTES BRICHETTI': "artes",
    'MARCO ENRIQUEZ-OMINAMI GUMUCIO': "meo",
    'FRANCO PARISI FERNANDEZ': "parisi",
    
    'CAROLINA GOIC BOROEVIC': "goic", 
    'SEBASTIAN PIÑERA ECHENIQUE': "pinera",
    'ALEJANDRO  GUILLIER ALVAREZ': "guillier",
    "MARCO  ENRIQUEZ-OMINAMI GUMUCIO": "meo",
    'BEATRIZ SANCHEZ MUÑOZ': "sanchez",
    
    'Constantin Ninel Potârcă': "potarca",
    'Constantin Rotaru': "rotaru",
    'Corneliu Vadim Tudor': "tudor",
    'Crin Antonescu': "antonescu",
    'George Becali': "becali",
    'Gheorghe-Eduard Manole': "manole",
    'Hunor Kelemen': "kelemen",
    'Mircea Geoană': "geoana",
    'Ovidiu Cristian Iane': "iane",
    'Remus Cernea': "cernea",
    'Sorin Oprescu': "oprescu",
    'Traian Băsescu': "basescu"
}

# %%
dd = df_a.pivot_table(
    index=["polling_id"],
    columns=["candidate"],
    values=["rate", "value", "divisiveness"]
).reset_index()

cols = []
for column in dd.columns:
    a, b = column
    new_column = None
    if not b:
        new_column = a
    else:
        new_column = f"{a}_{labels[b]}"
        
    cols.append(new_column)
    
dd.columns = cols
dd = pd.merge(dd, df_b, on="polling_id")
dd.to_csv(f"data_output/regression_{country}_{year}.csv", encoding="utf-8", index=False)
