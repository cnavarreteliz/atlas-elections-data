# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
year = 2009
country = "Romania"
location_level = "county_name"

# %%
df_location = pd.read_csv(f"data_output/{country}/{year}_first_round_location.csv.gzip", compression="gzip")
df_location = df_location.rename(columns={"electors": "voters"})
df_location.head()
# Out:
#    location_id location_id.1     Id  county_id  polling_place  \
# 0        87312         ALBAC  87312          1            193
# 1        87312         ALBAC  87312          1            194
# 2        87312         ALBAC  87312          1            195
# 3        87312         ALBAC  87312          1            196
# 4        87312         ALBAC  87312          1            197
#
#                                              address  location_id.2  \
# 0  Caminul cultural Albac, strada Closca, nr. 9, ...          87312
# 1  Scoala cu clasele I - IV Cionesti, sat. Ciones...          87312
# 2  Scoala cu clasele I - IV Costesti, sat. Costes...          87312
# 3  Scoala cu clasele I - IV Rogoz, sat. Rogoz, Sa...          87312
# 4  Scoala cu clasele I - IV Potionci, sat. Potion...          87312
#
#    county_id.1 county_name  election_id polling_id
# 0            1        Alba          261  261_1_193
# 1            1        Alba          261  261_1_194
# 2            1        Alba          261  261_1_195
# 3            1        Alba          261  261_1_196
# 4            1        Alba          261  261_1_197

# %%
df = pd.read_csv(f"data_output/{country}/{year}_first_round.csv.gzip", compression="gzip")
df.columns = [x.lower() for x in df.columns]
df = pd.merge(df, df_location, on="polling_id")
df.head()
# Out:
#   polling_id             candidate  value  rank      rate  location_id  \
# 0    261_1_1        Traian Băsescu    328     1  0.358862        87302
# 1    261_1_1        Crin Antonescu    282     2  0.308534        87302
# 2    261_1_1         Mircea Geoană    230     3  0.251641        87302
# 3    261_1_1  Corneliu Vadim Tudor     32     4  0.035011        87302
# 4    261_1_1         Sorin Oprescu     17     5  0.018600        87302
#
#            location_id.1     Id  county_id  polling_place  \
# 0  MUNICIPIUL ALBA IULIA  87302          1              1
# 1  MUNICIPIUL ALBA IULIA  87302          1              1
# 2  MUNICIPIUL ALBA IULIA  87302          1              1
# 3  MUNICIPIUL ALBA IULIA  87302          1              1
# 4  MUNICIPIUL ALBA IULIA  87302          1              1
#
#                                              address  location_id.2  \
# 0  Gradinita nr. 3, Str. Marasesti nr. 55 Tel:025...          87302
# 1  Gradinita nr. 3, Str. Marasesti nr. 55 Tel:025...          87302
# 2  Gradinita nr. 3, Str. Marasesti nr. 55 Tel:025...          87302
# 3  Gradinita nr. 3, Str. Marasesti nr. 55 Tel:025...          87302
# 4  Gradinita nr. 3, Str. Marasesti nr. 55 Tel:025...          87302
#
#    county_id.1 county_name  election_id
# 0            1        Alba          261
# 1            1        Alba          261
# 2            1        Alba          261
# 3            1        Alba          261
# 4            1        Alba          261

# %%
df_runoff = pd.read_csv(f"data_output/{country}/{year}_runoff.csv.gzip", compression="gzip")
df_runoff.columns = [x.lower() for x in df_runoff.columns]
df_runoff = pd.merge(df_runoff, df_location, on="polling_id")

df_runoff.head()
# Out:
#   polling_id       candidate  value  rank      rate  location_id  \
# 0    261_1_1  Traian Băsescu    493     1  0.536453        87302
# 1    261_1_1   Mircea Geoană    426     2  0.463547        87302
# 2    261_1_2  Traian Băsescu    412     1  0.575419        87302
# 3    261_1_2   Mircea Geoană    304     2  0.424581        87302
# 4    261_1_3  Traian Băsescu    491     1  0.554176        87302
#
#            location_id.1     Id  county_id  polling_place  \
# 0  MUNICIPIUL ALBA IULIA  87302          1              1
# 1  MUNICIPIUL ALBA IULIA  87302          1              1
# 2  MUNICIPIUL ALBA IULIA  87302          1              2
# 3  MUNICIPIUL ALBA IULIA  87302          1              2
# 4  MUNICIPIUL ALBA IULIA  87302          1              3
#
#                                              address  location_id.2  \
# 0  Gradinita nr. 3, Str. Marasesti nr. 55 Tel:025...          87302
# 1  Gradinita nr. 3, Str. Marasesti nr. 55 Tel:025...          87302
# 2  Scoala cu clasele I-VIII(nr.1) Vasile Goldis ,...          87302
# 3  Scoala cu clasele I-VIII(nr.1) Vasile Goldis ,...          87302
# 4  Scoala cu clasele I-VIII(nr. 3) Avram Iancu St...          87302
#
#    county_id.1 county_name  election_id
# 0            1        Alba          261
# 1            1        Alba          261
# 2            1        Alba          261
# 3            1        Alba          261
# 4            1        Alba          261

# %%
df_dv = pd.read_csv(f"data_output/{country}/{year}_divisiveness_{location_level}.csv.gzip", compression="gzip")
df_dv = df_dv.rename(columns={"alternative": "candidate"})

df_dv.head()
# Out:
#   county_name                 candidate     value
# 0        Alba  Constantin Ninel Potârcă  0.005179
# 1        Alba         Constantin Rotaru  0.005908
# 2        Alba      Corneliu Vadim Tudor  0.030255
# 3        Alba            Crin Antonescu  0.101979
# 4        Alba             George Becali  0.017440

# %%
# gdf = gpd.read_file("https://raw.githubusercontent.com/fcortes/Chile-GeoJSON/master/comunas.geojson")

# gdf["Comuna"] = gdf["Comuna"].apply(lambda x: x.upper())
# for a, b in [("Á", "A"), ("É", "E"), ("Í", "I"), ("Ó", "O"), ("Ú", "U"), ("Ü", "U")]:
#     gdf["Comuna"] = gdf["Comuna"].str.replace(a, b)

# gdf["Comuna"] = gdf["Comuna"].astype(str)
# gdf["Comuna"] = gdf["Comuna"].replace({
#     "TREGUACO": "TREHUACO",
#     "MARCHIHUE": "MARCHIGUE",
#     "PAIHUANO": "PAIGUANO",
#     "O'HIGGINS": "O'HIGGINS",
#     "CABO DE HORNOS": "CABO DE HORNOS(EX-NAVARINO)"
# })

# gdf = gdf.rename(columns={"Comuna": "commune"})

# gdf.head()

# %%
# df_tmp = pd.merge(df_runoff, df_location, on="polling_id")
# df_tmp = df_tmp.groupby(["commune", "candidate"]).agg({"value": "sum"})
# df_tmp["rate"] = df_tmp.groupby(level=[0]).apply(lambda x: x/x.sum())
# df_tmp = df_tmp.reset_index()
# df_tmp.head()

# %%
# dd = df_runoff.copy() #.groupby("commune").agg({"value": "mean"}).reset_index()
# dd = pd.merge(gdf, dd, on=location_level)
# dd["rank"] = dd.groupby(location_level)["value"].rank(ascending=False).astype(int)

# dd = dd[dd["rank"] == 1]

# fig, ax = plt.subplots(figsize=(10, 10), dpi=120)
# dd[~dd[location_level].isin(["ISLA DE PASCUA"])]\
#     .plot(
#     column="candidate",
#     edgecolor="black",
#     cmap="tab10",
#     lw=0.1,
#     ax=ax,
#     legend=True,
#     legend_kwds=dict(
#         loc="upper right",
#         bbox_to_anchor=(0.5, .9),
#         fontsize="small",
#         title="",
#         frameon=False
#     )
# )

# legend_kwds={"shrink": 0.3}
# cb = ax.get_figure().get_axes()[1]
# cb.set_yticklabels(["{0:.0f}%".format(ytick*100) for ytick in cb.get_yticks()])

# plt.axis("off")

# %%
import statsmodels.api as sm

# %%
df_location
# Out:
#        location_id location_id.1     Id  county_id  polling_place  \
# 0            87312         ALBAC  87312          1            193
# 1            87312         ALBAC  87312          1            194
# 2            87312         ALBAC  87312          1            195
# 3            87312         ALBAC  87312          1            196
# 4            87312         ALBAC  87312          1            197
# ...            ...           ...    ...        ...            ...
# 21701        90416       VULTURU  90416         41            426
# 21702        90416       VULTURU  90416         41            427
# 21703        90416       VULTURU  90416         41            428
# 21704        90416       VULTURU  90416         41            429
# 21705        90416       VULTURU  90416         41            430
#
#                                                  address  location_id.2  \
# 0      Caminul cultural Albac, strada Closca, nr. 9, ...          87312
# 1      Scoala cu clasele I - IV Cionesti, sat. Ciones...          87312
# 2      Scoala cu clasele I - IV Costesti, sat. Costes...          87312
# 3      Scoala cu clasele I - IV Rogoz, sat. Rogoz, Sa...          87312
# 4      Scoala cu clasele I - IV Potionci, sat. Potion...          87312
# ...                                                  ...            ...
# 21701                           BOTIRLAU SCOALA GENERALA          90416
# 21702                         HINGULESTI SCOALA GENERALA          90416
# 21703                                      MALURI SCOALA          90416
# 21704                                  VADU ROSCA SCOALA          90416
# 21705                         PRIMARIA  VULTURU SPECIALA          90416
#
#        county_id.1 county_name  election_id  polling_id
# 0                1        Alba          261   261_1_193
# 1                1        Alba          261   261_1_194
# 2                1        Alba          261   261_1_195
# 3                1        Alba          261   261_1_196
# 4                1        Alba          261   261_1_197
# ...            ...         ...          ...         ...
# 21701           41     Vrancea          261  261_41_426
# 21702           41     Vrancea          261  261_41_427
# 21703           41     Vrancea          261  261_41_428
# 21704           41     Vrancea          261  261_41_429
# 21705           41     Vrancea          261  261_41_430
#
# [21706 rows x 11 columns]

# %%
# df_voters = df_location.groupby(location_level).agg({"voters": "sum"}).reset_index()
# df_voters.head()

# %%
df_tmp = df.groupby([location_level, "candidate"]).agg({"value": "sum"})
df_tmp["rate"] = df_tmp.groupby(level=[0]).apply(lambda x: x/x.sum())
df_tmp = df_tmp.reset_index()
df_tmp.head()
# Out:
#   county_name                 candidate  value      rate
# 0        Alba  Constantin Ninel Potârcă    380  0.002142
# 1        Alba         Constantin Rotaru    454  0.002560
# 2        Alba      Corneliu Vadim Tudor   7575  0.042707
# 3        Alba            Crin Antonescu  37810  0.213168
# 4        Alba             George Becali   3778  0.021300

# %%
df_hhi = df_tmp.copy()
df_hhi["hhi"] = df_hhi["rate"] ** 2
df_hhi["entropy"] = df_hhi["rate"] * np.log(df_hhi["rate"])
df_hhi = df_hhi.groupby(location_level).agg({"hhi": "sum", "entropy": "sum"})
df_hhi["entropy"] = -1 * df_hhi["entropy"]
df_hhi = df_hhi.reset_index()
df_hhi.head()
# Out:
#   county_name       hhi   entropy
# 0        Alba  0.284475  1.522293
# 1        Arad  0.297668  1.521669
# 2       Arges  0.277299  1.518622
# 3       Bacau  0.258740  1.563909
# 4       Bihor  0.216528  1.703072

# %%
df_model = df_runoff.groupby([location_level, "candidate"]).agg({"value": "sum"})

df_model["rate"] = df_model.groupby(level=[0]).apply(lambda x: x/x.sum())

df_model = df_model.rename(columns={"value": "votes"}).reset_index()

df_model = pd.merge(df_model, df_dv.rename(columns={"value": "divisiveness"}), on=[location_level, "candidate"])

df_model = pd.merge(df_tmp, df_model, on=[location_level, "candidate"])

if country != "Romania":
    df_model = pd.merge(df_model, df_voters, on=location_level)

if country == "France":
    df_poverty = pd.read_excel("data_external/France/poverty_2017.xlsx", sheet_name="Figure 3", header=2).dropna()
    df_poverty["Taux de pauvreté"] = df_poverty["Taux de pauvreté"].astype(float) / 100
    df_poverty = df_poverty.rename(columns={"Code": "geo_id", "Département": "department", "Taux de pauvreté": "poverty_rate"})
    
elif country == "Chile":
    df_poverty = pd.read_excel("data_external/Chile/poverty_2020.xlsx", header=2)
    df_poverty = df_poverty[~df_poverty["Nombre comuna"].isna()]
    df_poverty = df_poverty.rename(columns={"Nombre comuna": "commune", "Porcentaje de personas en situación de pobreza por ingresos 2020": "poverty_rate"})
    df_poverty["commune"] = df_poverty["commune"].apply(lambda x: x.upper())

    for a, b in [("Á", "A"), ("É", "E"), ("Í", "I"), ("Ó", "O"), ("Ú", "U"), ("Ü", "U")]:
        df_poverty["commune"] = df_poverty["commune"].str.replace(a, b)
    df_poverty["commune"] = df_poverty["commune"].astype(str)
    df_poverty["commune"] = df_poverty["commune"].replace(
        {"TREGUACO": "TREHUACO", "MARCHIHUE": "MARCHIGUE", "PAIGUANO": "PAIHUANO", "O’HIGGINS": "O'HIGGINS", "CABO DE HORNOS": "CABO DE HORNOS(EX-NAVARINO)"})

    df_poverty = df_poverty[["commune", "poverty_rate"]]

if country in ["Chile", "France"]:
    df_model = pd.merge(df_model, df_poverty, on=location_level)
    
df_model = pd.merge(df_model, df_hhi, on=location_level)

df_model["growth"] = df_model["rate_y"] - df_model["rate_x"]

df_model = df_model.dropna()
df_model.to_csv(f"data_output/data_model_{country}_{year}.csv", index=False)

df_model
# Out:
#    county_name       candidate   value    rate_x   votes    rate_y  \
# 0         Alba   Mircea Geoană   41188  0.232213   76037  0.398104
# 1         Alba  Traian Băsescu   75595  0.426195  114961  0.601896
# 2         Arad   Mircea Geoană   41651  0.206910   80865  0.360707
# 3         Arad  Traian Băsescu   94186  0.467889  143320  0.639293
# 4        Arges   Mircea Geoană  127978  0.419581  191679  0.587807
# ..         ...             ...     ...       ...     ...       ...
# 81      Valcea  Traian Băsescu   56427  0.282535   90801  0.429506
# 82      Vaslui   Mircea Geoană   77607  0.443474  111058  0.599902
# 83      Vaslui  Traian Băsescu   45629  0.260740   74069  0.400098
# 84     Vrancea   Mircea Geoană   70865  0.425611   97408  0.550536
# 85     Vrancea  Traian Băsescu   49704  0.298519   79525  0.449464
#
#     divisiveness       hhi   entropy    growth
# 0       0.091674  0.284475  1.522293  0.165891
# 1       0.129582  0.284475  1.522293  0.175702
# 2       0.091483  0.297668  1.521669  0.153796
# 3       0.118498  0.297668  1.521669  0.171405
# 4       0.116469  0.277299  1.518622  0.168226
# ..           ...       ...       ...       ...
# 81      0.086869  0.276519  1.492671  0.146971
# 82      0.128307  0.294342  1.493572  0.156428
# 83      0.106420  0.294342  1.493572  0.139358
# 84      0.132955  0.302003  1.430456  0.124926
# 85      0.095855  0.302003  1.430456  0.150945
#
# [86 rows x 10 columns]

# %%
# gdf = gpd.read_file("https://raw.githubusercontent.com/fcortes/Chile-GeoJSON/master/comunas.geojson")

# gdf["Comuna"] = gdf["Comuna"].apply(lambda x: x.upper())
# for a, b in [("Á", "A"), ("É", "E"), ("Í", "I"), ("Ó", "O"), ("Ú", "U"), ("Ü", "U")]:
#     gdf["Comuna"] = gdf["Comuna"].str.replace(a, b)

# gdf["Comuna"] = gdf["Comuna"].astype(str)
# gdf["Comuna"] = gdf["Comuna"].replace({
#     "TREGUACO": "TREHUACO",
#     "MARCHIHUE": "MARCHIGUE",
#     "PAIHUANO": "PAIGUANO",
#     "O'HIGGINS": "O'HIGGINS",
#     "CABO DE HORNOS": "CABO DE HORNOS(EX-NAVARINO)"
# })

# gdf = gdf.rename(columns={"Comuna": "commune"})

# gdf.head()

# %%
df_dv.candidate.unique()
# Out:
# array(['Constantin Ninel Potârcă', 'Constantin Rotaru',
#        'Corneliu Vadim Tudor', 'Crin Antonescu', 'George Becali',
#        'Gheorghe-Eduard Manole', 'Hunor Kelemen', 'Mircea Geoană',
#        'Ovidiu Cristian Iane', 'Remus Cernea', 'Sorin Oprescu',
#        'Traian Băsescu'], dtype=object)

# %%
# df_dv

# %%
dd = df.groupby("candidate").agg({"value": "sum"})
dd["rate"] = dd.apply(lambda x: x/x.sum())
values = list(dd[dd["rate"] < 0.01].index.unique())
values
# Out:
# ['Corneliu Vadim Tudor',
#  'Crin Antonescu',
#  'Hunor Kelemen',
#  'Mircea Geoană',
#  'Sorin Oprescu',
#  'Traian Băsescu']

# %%
location = "polling_id"

def get_rate(df, location=["polling_id"], level=[0]):
    df_tmp = df[~df["candidate"].isin(values)].groupby(location + ["candidate"]).agg({"value": "sum"})
    df_tmp["rate"] = df_tmp.groupby(level=level).apply(lambda x: x/x.sum())
    df_tmp = df_tmp.reset_index()

    return df_tmp

df_a = get_rate(df, location=[location_level, "polling_id"], level=[0, 1])
df_a = pd.merge(df_a, df_dv.rename(columns={"value": "divisiveness"}), on=[location_level, "candidate"])

df_b = get_rate(df_runoff)

# %%
df_a.candidate.unique()
# Out:
# array(['Corneliu Vadim Tudor', 'Crin Antonescu', 'George Becali',
#        'Hunor Kelemen', 'Mircea Geoană', 'Sorin Oprescu',
#        'Traian Băsescu'], dtype=object)

# %%
labels = {
    'Anne HIDALGO': "hidalgo",
    'Emmanuel MACRON': "macron",
    'Fabien ROUSSEL': "roussel",
    'Jean LASSALLE': "lassalle", 
    'Jean-Luc MÉLENCHON': "melenchon", 
    'Marine LE PEN': "le_pen",
    'Nathalie ARTHAUD': "arthaud", 
    'Nicolas DUPONT-AIGNAN': "dupont",
    'Philippe POUTOU': "poutou",
    'Valérie PÉCRESSE': "pecresse", 
    'Yannick JADOT': "jadot",
    'Éric ZEMMOUR': "zemmour",
    
    'ALVARO FERNANDES DIAS': "alvaro",
    'BENEVENUTO DACIOLO FONSECA DOS SANTOS': "daciolo",
    'CIRO FERREIRA GOMES': "ciro",
    'FERNANDO HADDAD': "haddad",
    'GERALDO JOSÉ RODRIGUES ALCKMIN FILHO': "alckmin",
    'GUILHERME CASTRO BOULOS': "boulos",
    'HENRIQUE DE CAMPOS MEIRELLES': "meirelles",
    'JAIR MESSIAS BOLSONARO': "bolsonaro",
    'JOSE MARIA EYMAEL': "eymael",
    'JOÃO DIONISIO FILGUEIRA BARRETO AMOEDO': "amoedo",
    'JOÃO VICENTE FONTELLA GOULART': "goulart",
    'MARIA OSMARINA MARINA DA SILVA VAZ DE LIMA': "da_silva",
    'VERA LUCIA PEREIRA DA SILVA SALGADO': "vera_lucia",
    
    'GABRIEL BORIC FONT': "boric",
    'JOSE ANTONIO KAST RIST': "kast",
    'YASNA PROVOSTE CAMPILLAY': "provoste",
    'SEBASTIAN SICHEL RAMIREZ': "sichel",
    'EDUARDO ARTES BRICHETTI': "artes",
    'MARCO ENRIQUEZ-OMINAMI GUMUCIO': "meo",
    'FRANCO PARISI FERNANDEZ': "parisi",
    
    'CAROLINA GOIC BOROEVIC': "goic", 
    'SEBASTIAN PIÑERA ECHENIQUE': "pinera",
    'ALEJANDRO  GUILLIER ALVAREZ': "guillier",
    "MARCO  ENRIQUEZ-OMINAMI GUMUCIO": "meo",
    'BEATRIZ SANCHEZ MUÑOZ': "sanchez",
    
    'Constantin Ninel Potârcă': "potarca",
    'Constantin Rotaru': "rotaru",
    'Corneliu Vadim Tudor': "tudor",
    'Crin Antonescu': "antonescu",
    'George Becali': "becali",
    'Gheorghe-Eduard Manole': "manole",
    'Hunor Kelemen': "kelemen",
    'Mircea Geoană': "geoana",
    'Ovidiu Cristian Iane': "iane",
    'Remus Cernea': "cernea",
    'Sorin Oprescu': "oprescu",
    'Traian Băsescu': "basescu"
}

# %%
dd = df_a.pivot_table(
    index=["polling_id"],
    columns=["candidate"],
    values=["rate", "value", "divisiveness"]
).reset_index()

cols = []
for column in dd.columns:
    a, b = column
    new_column = None
    if not b:
        new_column = a
    else:
        new_column = f"{a}_{labels[b]}"
        
    cols.append(new_column)
    
dd.columns = cols
dd = pd.merge(dd, df_b, on="polling_id")
dd.to_csv(f"data_output/regression_{country}_{year}.csv", encoding="utf-8", index=False)

# %%
dd
# Out:
#        polling_id  divisiveness_tudor  divisiveness_antonescu  \
# 0        261_10_1            0.026359                0.126692
# 1        261_10_1            0.026359                0.126692
# 2       261_10_10            0.026359                0.126692
# 3       261_10_10            0.026359                0.126692
# 4      261_10_100            0.026359                0.126692
# ...           ...                 ...                     ...
# 43405    261_9_97            0.029025                0.084660
# 43406    261_9_98            0.029025                0.084660
# 43407    261_9_98            0.029025                0.084660
# 43408    261_9_99            0.029025                0.084660
# 43409    261_9_99            0.029025                0.084660
#
#        divisiveness_becali  divisiveness_kelemen  divisiveness_geoana  \
# 0                 0.014974                   NaN             0.127966
# 1                 0.014974                   NaN             0.127966
# 2                 0.014974                   NaN             0.127966
# 3                 0.014974                   NaN             0.127966
# 4                 0.014974              0.004175             0.127966
# ...                    ...                   ...                  ...
# 43405             0.017792              0.003556             0.107686
# 43406             0.017792                   NaN             0.107686
# 43407             0.017792                   NaN             0.107686
# 43408             0.017792              0.003556             0.107686
# 43409             0.017792              0.003556             0.107686
#
#        divisiveness_oprescu  divisiveness_basescu  rate_tudor  rate_antonescu  \
# 0                  0.024541              0.093735    0.056522        0.269565
# 1                  0.024541              0.093735    0.056522        0.269565
# 2                  0.024541              0.093735    0.063510        0.173210
# 3                  0.024541              0.093735    0.063510        0.173210
# 4                  0.024541              0.093735    0.082119        0.227815
# ...                     ...                   ...         ...             ...
# 43405              0.026503              0.081555    0.090468        0.127625
# 43406              0.026503              0.081555    0.112583        0.125828
# 43407              0.026503              0.081555    0.112583        0.125828
# 43408              0.026503              0.081555    0.077348        0.214365
# 43409              0.026503              0.081555    0.077348        0.214365
#
#        ...  value_tudor  value_antonescu  value_becali  value_kelemen  \
# 0      ...         52.0            248.0          27.0            NaN
# 1      ...         52.0            248.0          27.0            NaN
# 2      ...         55.0            150.0          35.0            NaN
# 3      ...         55.0            150.0          35.0            NaN
# 4      ...         62.0            172.0          26.0            1.0
# ...    ...          ...              ...           ...            ...
# 43405  ...         56.0             79.0          19.0            1.0
# 43406  ...         51.0             57.0          21.0            NaN
# 43407  ...         51.0             57.0          21.0            NaN
# 43408  ...         70.0            194.0          16.0            1.0
# 43409  ...         70.0            194.0          16.0            1.0
#
#        value_geoana  value_oprescu  value_basescu       candidate  value  \
# 0             282.0           60.0          251.0   Mircea Geoană    560
# 1             282.0           60.0          251.0  Traian Băsescu    399
# 2             292.0           65.0          269.0   Mircea Geoană    500
# 3             292.0           65.0          269.0  Traian Băsescu    436
# 4             225.0           62.0          207.0   Mircea Geoană    445
# ...             ...            ...            ...             ...    ...
# 43405         248.0           35.0          181.0  Traian Băsescu    314
# 43406         179.0           33.0          112.0   Mircea Geoană    281
# 43407         179.0           33.0          112.0  Traian Băsescu    219
# 43408         349.0           61.0          214.0   Mircea Geoană    561
# 43409         349.0           61.0          214.0  Traian Băsescu    388
#
#            rate
# 0      0.583942
# 1      0.416058
# 2      0.534188
# 3      0.465812
# 4      0.580183
# ...         ...
# 43405  0.475758
# 43406  0.562000
# 43407  0.438000
# 43408  0.591149
# 43409  0.408851
#
# [43410 rows x 25 columns]

# %%
fig, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(dd.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# dd = df_dv.groupby("commune").agg({"value": "mean"}).reset_index()
# # dd = dd[dd["candidate"] == "FRANCO PARISI FERNANDEZ"]
# dd = pd.merge(gdf, dd, on=location_level)
# # dd["rank"] = dd.groupby(location_level)["value"].rank(ascending=False).astype(int)

# # dd = dd[dd["rank"] == 1]
# def NormalizeData(data):
#     return (data - np.min(data)) / (np.max(data) - np.min(data))

# dd["value"] = dd["value"].apply(lambda x: x ** 2)

# fig, ax = plt.subplots(figsize=(10, 10), dpi=140)
# dd[~dd[location_level].isin(["ISLA DE PASCUA"])]\
#     .plot(
#     column="value",
#     edgecolor="black",
#     cmap="coolwarm",
#     lw=0.1,
#     ax=ax,
#     legend=True,
#     legend_kwds=dict(
#         shrink=0.3
#     )
# )

# # legend_kwds={"shrink": 0.3}
# # cb = ax.get_figure().get_axes()[1]
# # cb.set_yticklabels(["{0:.0f}%".format(ytick*100) for ytick in cb.get_yticks()])

# plt.axis("off")
