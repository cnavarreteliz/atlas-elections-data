# %%
import pandas as pd
import numpy as np
import networkx as nx
import requests

from epitools import get_data

# %%
year = 2017
if year >= 2016:
    URL = f"https://www2.census.gov/programs-surveys/demo/tables/geographic-mobility/{year}/state-to-state-migration/State_to_State_Migrations_Table_{year}.xls"
else:
    URL = f"https://www2.census.gov/programs-surveys/demo/tables/geographic-mobility/{year}/state-to-state-migration/state_to_state_migrations_table_{year}.xls"

df = pd.read_excel(
    URL,
    header=6
)
df = df.rename(columns={"Unnamed: 0": "state_target"}) #, "Unnamed: 1": "population"
df["year"] = year

columns = list(filter(lambda x: "Unnamed" not in x and "Total" not in x, list(df)))
df = df[columns].dropna(subset=["state_target"])
df = df[~df["state_target"].isin(["United States1", "United States2", "Current residence in --"])].head(52).replace("N/A2", np.nan)

df.head()
# Out:
#   state_target Alabama Alaska Arizona Arkansas California Colorado  \
# 4      Alabama     NaN    424    1513      517       2328     1974
# 5       Alaska     942    NaN    1387      203       3556     1487
# 6      Arizona    1337   2255     NaN     1763      59233    12810
# 7     Arkansas     574    241    1060      NaN       5334     2547
# 8   California    3715   2606   26907     3471        NaN    25038
#
#   Connecticut Delaware District of Columbia   ... Vermont Virginia Washington  \
# 4         336       22                   378  ...       0     4277       1289
# 5           0        0                     0  ...       0      360       3653
# 6         730      810                   362  ...      96     3593      14392
# 7           0        0                     0  ...       0     1087       1539
# 8        5935      491                  6818  ...     895    21162      33143
#
#   West Virginia Wisconsin Wyoming Puerto Rico U.S. Island Area  \
# 4          1070      1121     104         476                0
# 5             0      2500       6           0              965
# 6           318      3897     997         438               91
# 7             0       958      12         573                0
# 8           789      9348    1395        1864              842
#
#   Foreign Country4  year
# 4            13191  2017
# 5             5738  2017
# 6            44793  2017
# 7             8385  2017
# 8           316046  2017
#
# [5 rows x 56 columns]

# %%
dd = df.melt(id_vars=["state_target", "year"], var_name="state_origin", value_name="migration").dropna()
dd
# Out:
#        state_target  year      state_origin migration
# 1            Alaska  2017           Alabama       942
# 2           Arizona  2017           Alabama      1337
# 3          Arkansas  2017           Alabama       574
# 4        California  2017           Alabama      3715
# 5          Colorado  2017           Alabama      3120
# ...             ...   ...               ...       ...
# 2803     Washington  2017  Foreign Country4     61405
# 2804  West Virginia  2017  Foreign Country4      2988
# 2805      Wisconsin  2017  Foreign Country4     20492
# 2806        Wyoming  2017  Foreign Country4      2403
# 2807    Puerto Rico  2017  Foreign Country4      2889
#
# [2756 rows x 4 columns]

# %%
aa = dd.pivot(index="state_origin", columns="state_target", values="migration")
aa = aa.loc[list(aa.columns)]
aa.head()
# Out:
# state_target Alabama Alaska Arizona Arkansas California Colorado Connecticut  \
# state_origin
# Alabama          NaN    942    1337      574       3715     3120         206
# Alaska           424    NaN    2255      241       2606     2030         540
# Arizona         1513   1387     NaN     1060      26907     6765         644
# Arkansas         517    203    1763      NaN       3471     1356         160
# California      2328   3556   59233     5334        NaN    27014        2807
#
# state_target Delaware District of Columbia  Florida  ... South Dakota  \
# state_origin                                         ...
# Alabama           506                   494    9389  ...          144
# Alaska              0                     0    1400  ...          183
# Arizona            76                   549    5577  ...          402
# Arkansas            0                   105    3028  ...           83
# California        580                  3763   30919  ...         3599
#
# state_target Tennessee  Texas   Utah Vermont Virginia Washington  \
# state_origin
# Alabama           9523  10235    644       0     2341       1605
# Alaska             417   3543    660     203      736       7532
# Arizona           2522  14875   8144     132     2587      11733
# Arkansas          5843  14222    177       0     1184       1074
# California        7879  63174  17020    1246    14509      52484
#
# state_target West Virginia Wisconsin Wyoming
# state_origin
# Alabama                239       757     264
# Alaska                 121       389     152
# Arizona                 13      1702     220
# Arkansas                 0       601     722
# California             563      4741    2344
#
# [5 rows x 52 columns]

# %%
test = (aa > aa.T).reset_index().melt(id_vars=["state_origin"], value_name="in_out")
test["in_out"] = test["in_out"].astype(int)
test = test[test["state_origin"] != test["state_target"]]
test["year"] = year - 1
for suffix in ["origin", "target"]:
    test[f"state_{suffix}"] = test[f"state_{suffix}"].str.upper()

test
# Out:
#        state_origin state_target  in_out  year
# 1            ALASKA      ALABAMA       0  2016
# 2           ARIZONA      ALABAMA       1  2016
# 3          ARKANSAS      ALABAMA       0  2016
# 4        CALIFORNIA      ALABAMA       0  2016
# 5          COLORADO      ALABAMA       0  2016
# ...             ...          ...     ...   ...
# 2698        VERMONT      WYOMING       0  2016
# 2699       VIRGINIA      WYOMING       1  2016
# 2700     WASHINGTON      WYOMING       1  2016
# 2701  WEST VIRGINIA      WYOMING       0  2016
# 2702      WISCONSIN      WYOMING       0  2016
#
# [2652 rows x 4 columns]

# %%
output = []
method = "nv"

for year in [2000, 2004, 2008, 2012, 2016, 2020]:
    df_tmp = get_data(
        country="United States",
        year=year,
        aggregation="state",
        election="first_round",
        method=method
    )
    df_tmp["year"] = year
    
    output.append(df_tmp)

df_dv = pd.concat(output, ignore_index=True)
df_dv["state"] = df_dv["state"].str.upper()
df_dv["year"] = df_dv["year"].astype(int)
df_dv = df_dv.rename(columns={"epi": "value"})
df_dv.head()
# Out:
#         state     value  epi_between  epi_within  year
# 0     ALABAMA  0.954538     0.812398    0.142140  2000
# 1      ALASKA  0.791327     0.648163    0.143164  2000
# 2     ARIZONA  0.969194     0.886976    0.082218  2000
# 3    ARKANSAS  0.992210     0.842943    0.149267  2000
# 4  CALIFORNIA  0.997502     0.782541    0.214961  2000

# %%
df_gini = pd.read_csv("data_curated/United States/Income_Inequality.csv")
df_gini.head()
# Out:
#    year          state      gini  moe
# 0  1917  UNITED STATES  0.507681  NaN
# 1  1917        ALABAMA  0.399792  NaN
# 2  1917        ARIZONA  0.399658  NaN
# 3  1917       ARKANSAS  0.376483  NaN
# 4  1917     CALIFORNIA  0.449363  NaN

# %%
def clean_bea_data(
    PATH,
    value_name="value"
):
    tmp = pd.read_csv(PATH, header=3).dropna(subset=["GeoName"])
    tmp = tmp.melt(id_vars=["GeoFips", "GeoName"], var_name="year", value_name=value_name)
    tmp = tmp.rename(columns={"GeoFips": "state_id", "GeoName": "state"})
    tmp = tmp[~(tmp["state_id"].str[0] == "9")]
    tmp = tmp[tmp[value_name] != "(NA)"]
    tmp = tmp[tmp["state_id"] != "00000"]
    tmp["state"] = tmp["state"].replace({" *": ""}).str.upper()
    tmp = tmp.drop(columns=["state_id"])
    tmp[value_name] = tmp[value_name].astype(float)
    tmp["year"] = tmp["year"].astype(int)

    return tmp


df_personal_income = clean_bea_data(
    PATH="data_external/United States/BEA_Personal_income.csv",
    value_name="personal_income"
)
df_personal_income.head()
# Out:
#         state  year  personal_income
# 1     ALABAMA  1929            319.0
# 3     ARIZONA  1929            598.0
# 4    ARKANSAS  1929            303.0
# 5  CALIFORNIA  1929            994.0
# 6    COLORADO  1929            631.0

# %%
cc = pd.merge(test, df_dv, left_on=["state_origin", "year"], right_on=["state", "year"])
cc = pd.merge(cc, df_dv, left_on=["state_target", "year"], right_on=["state", "year"])
cc = pd.merge(cc, df_gini, left_on=["state_origin", "year"], right_on=["state", "year"])
cc = pd.merge(cc, df_gini, left_on=["state_target", "year"], right_on=["state", "year"])
cc = pd.merge(cc, df_personal_income, left_on=["state_origin", "year"], right_on=["state", "year"])
cc = pd.merge(cc, df_personal_income, left_on=["state_target", "year"], right_on=["state", "year"])

cc["epi_in_out"] = cc["value_x"] > cc["value_y"]
cc["epi_diff"] = cc["value_x"] - cc["value_y"]
cc["epi_diff_between"] = cc["epi_between_x"] - cc["epi_between_y"]
cc["epi_diff_within"] = cc["epi_within_x"] - cc["epi_within_y"]

cc.to_csv("test.csv")
cc
# Out:
# C:\Users\cnava\AppData\Local\Temp\ipykernel_36608\3333025555.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'state_x'} in the result is deprecated and will raise a MergeError in a future version.
#   cc = pd.merge(cc, df_gini, left_on=["state_target", "year"], right_on=["state", "year"])
# C:\Users\cnava\AppData\Local\Temp\ipykernel_36608\3333025555.py:6: FutureWarning: Passing 'suffixes' which cause duplicate columns {'state_x'} in the result is deprecated and will raise a MergeError in a future version.
#   cc = pd.merge(cc, df_personal_income, left_on=["state_target", "year"], right_on=["state", "year"])
#        state_origin state_target  in_out  year        state_x   value_x  \
# 0           ARIZONA      ALABAMA       1  2016        ARIZONA  0.987250
# 1          ARKANSAS      ALABAMA       0  2016       ARKANSAS  0.888906
# 2        CALIFORNIA      ALABAMA       0  2016     CALIFORNIA  0.899948
# 3          COLORADO      ALABAMA       0  2016       COLORADO  0.988376
# 4       CONNECTICUT      ALABAMA       1  2016    CONNECTICUT  0.916482
# ...             ...          ...     ...   ...            ...       ...
# 2251     WASHINGTON      ARIZONA       1  2016     WASHINGTON  0.975183
# 2252  WEST VIRGINIA      ARIZONA       1  2016  WEST VIRGINIA  0.709818
# 2253      WISCONSIN      ARIZONA       1  2016      WISCONSIN  0.997991
# 2254        WYOMING      ARIZONA       1  2016        WYOMING  0.702832
# 2255        ALABAMA      ARIZONA       0  2016        ALABAMA  0.935563
#
#       epi_between_x  epi_within_x  state_y   value_y  ...  gini_y    moe_y  \
# 0          0.891965      0.095286  ALABAMA  0.935563  ...  0.4769  ±0.0019
# 1          0.650742      0.238164  ALABAMA  0.935563  ...  0.4769  ±0.0019
# 2          0.669357      0.230591  ALABAMA  0.935563  ...  0.4769  ±0.0019
# 3          0.743760      0.244617  ALABAMA  0.935563  ...  0.4769  ±0.0019
# 4          0.835912      0.080569  ALABAMA  0.935563  ...  0.4769  ±0.0019
# ...             ...           ...      ...       ...  ...     ...      ...
# 2251       0.741111      0.234072  ARIZONA  0.987250  ...  0.4682  ±0.0018
# 2252       0.571399      0.138420  ARIZONA  0.987250  ...  0.4682  ±0.0018
# 2253       0.751453      0.246538  ARIZONA  0.987250  ...  0.4682  ±0.0018
# 2254       0.489195      0.213637  ARIZONA  0.987250  ...  0.4682  ±0.0018
# 2255       0.653429      0.282135  ARIZONA  0.987250  ...  0.4682  ±0.0018
#
#             state_x  personal_income_x  state_y personal_income_y  epi_in_out  \
# 0           ARIZONA            41473.0  ALABAMA           39014.0        True
# 1          ARKANSAS            40873.0  ALABAMA           39014.0       False
# 2        CALIFORNIA            56560.0  ALABAMA           39014.0       False
# 3          COLORADO            52390.0  ALABAMA           39014.0        True
# 4       CONNECTICUT            68680.0  ALABAMA           39014.0       False
# ...             ...                ...      ...               ...         ...
# 2251     WASHINGTON            54918.0  ARIZONA           41473.0       False
# 2252  WEST VIRGINIA            37380.0  ARIZONA           41473.0       False
# 2253      WISCONSIN            47205.0  ARIZONA           41473.0        True
# 2254        WYOMING            54827.0  ARIZONA           41473.0       False
# 2255        ALABAMA            39014.0  ARIZONA           41473.0       False
#
#       epi_diff epi_diff_between  epi_diff_within
# 0     0.051687         0.238536        -0.186849
# 1    -0.046657        -0.002686        -0.043971
# 2    -0.035615         0.015929        -0.051544
# 3     0.052813         0.090331        -0.037518
# 4    -0.019082         0.182484        -0.201565
# ...        ...              ...              ...
# 2251 -0.012067        -0.150854         0.138787
# 2252 -0.277432        -0.320566         0.043134
# 2253  0.010740        -0.140512         0.151252
# 2254 -0.284418        -0.402769         0.118351
# 2255 -0.051687        -0.238536         0.186849
#
# [2256 rows x 26 columns]

# %%
cc[cc["state_target"] == "CALIFORNIA"]
# Out:
#        state_origin state_target  in_out  year         state_x   value_x  \
# 94          ARIZONA   CALIFORNIA       0  2016         ARIZONA  0.987250
# 95         ARKANSAS   CALIFORNIA       0  2016        ARKANSAS  0.888906
# 96         COLORADO   CALIFORNIA       0  2016        COLORADO  0.988376
# 97      CONNECTICUT   CALIFORNIA       1  2016     CONNECTICUT  0.916482
# 98         DELAWARE   CALIFORNIA       0  2016        DELAWARE  0.981587
# 99          FLORIDA   CALIFORNIA       0  2016         FLORIDA  0.998440
# 100         GEORGIA   CALIFORNIA       0  2016         GEORGIA  1.005585
# 101           IDAHO   CALIFORNIA       0  2016           IDAHO  0.854455
# 102        ILLINOIS   CALIFORNIA       1  2016        ILLINOIS  0.977230
# 103         INDIANA   CALIFORNIA       0  2016         INDIANA  0.938855
# 104            IOWA   CALIFORNIA       1  2016            IOWA  0.993059
# 105          KANSAS   CALIFORNIA       0  2016          KANSAS  0.959149
# 106        KENTUCKY   CALIFORNIA       0  2016        KENTUCKY  0.886464
# 107       LOUISIANA   CALIFORNIA       0  2016       LOUISIANA  0.932329
# 108           MAINE   CALIFORNIA       1  2016           MAINE  0.998914
# 127    PENNSYLVANIA            51181.0  CALIFORNIA           56560.0
# 128    RHODE ISLAND            49184.0  CALIFORNIA           56560.0
# 129  SOUTH CAROLINA            41178.0  CALIFORNIA           56560.0
# 130    SOUTH DAKOTA            49192.0  CALIFORNIA           56560.0
# 131       TENNESSEE            43499.0  CALIFORNIA           56560.0
# 132           TEXAS            46586.0  CALIFORNIA           56560.0
# 133            UTAH            41750.0  CALIFORNIA           56560.0
# 134         VERMONT            49621.0  CALIFORNIA           56560.0
# 135        VIRGINIA            53268.0  CALIFORNIA           56560.0
# 136      WASHINGTON            54918.0  CALIFORNIA           56560.0
# 137   WEST VIRGINIA            37380.0  CALIFORNIA           56560.0
# 138       WISCONSIN            47205.0  CALIFORNIA           56560.0
# 139         WYOMING            54827.0  CALIFORNIA           56560.0
# 140         ALABAMA            39014.0  CALIFORNIA           56560.0
#
#      epi_in_out  epi_diff epi_diff_between  epi_diff_within
# 94         True  0.087302         0.222607        -0.135306
# 95        False -0.011042        -0.018615         0.007572
# 96         True  0.088428         0.074402         0.014026
# 97         True  0.016533         0.166555        -0.150022
# 98         True  0.081638         0.084474        -0.002836
# 99         True  0.098492         0.105430        -0.006938
# 100        True  0.105637        -0.024481         0.130117
# 101       False -0.045493        -0.027420        -0.018073
# 102        True  0.077281         0.000237         0.077044
# 103        True  0.038907         0.029191         0.009715
# 104        True  0.093111         0.124003        -0.030892
# 105        True  0.059201         0.063164        -0.003963
# 106       False -0.013485        -0.028771         0.015286
# 107        True  0.032380        -0.014917         0.047297
# 108        True  0.098966         0.187691        -0.088725
# 109        True  0.078313        -0.054426         0.132740
# 110       False -0.041658         0.047054        -0.088712
# 111        True  0.099864         0.110760        -0.010896
# 112        True  0.099751         0.070247         0.029504
# 113        True  0.047223        -0.011455         0.058678
# 114        True  0.053179        -0.044910         0.098089
# 115        True  0.041649         0.056700        -0.015051
# 116        True  0.098095         0.067246         0.030849
# 117        True  0.085466         0.194679        -0.109212
# 118        True  0.101402         0.268240        -0.166838
# 119        True  0.062088         0.086518        -0.024431
# 120        True  0.069625         0.047696         0.021929
# 121        True  0.111090         0.027367         0.083723
# 122        True  0.100268         0.055927         0.044341
# 123       False -0.081746        -0.052992        -0.028755
# 124        True  0.097252         0.065955         0.031297
# 125       False -0.081127        -0.037089        -0.044038
# 126        True  0.094928         0.047338         0.047590
# 127        True  0.100546         0.055380         0.045166
# 128        True  0.010906         0.163302        -0.152396
# 129        True  0.046906         0.073014        -0.026109
# 130       False -0.088708        -0.005227        -0.083481
# 131       False -0.000071        -0.061459         0.061388
# 132        True  0.098390         0.032415         0.065975
# 133        True  0.074700         0.002640         0.072060
# 134       False -0.036508         0.033679        -0.070187
# 135        True  0.100434         0.030384         0.070050
# 136        True  0.075235         0.071754         0.003481
# 137       False -0.190130        -0.097958        -0.092171
# 138        True  0.098042         0.082096         0.015947
# 139       False -0.197116        -0.180162        -0.016954
# 140        True  0.035615        -0.015929         0.051544
#
# [47 rows x 26 columns]

# %%
# aa - np.tile(aa.mean(axis=0), (52, 1)).T > 0
