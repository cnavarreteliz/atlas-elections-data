# %%
import geopandas as gpd
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib

os.chdir("../")
from epitools import get_data

# %%
gdf_ca = gpd.read_file("https://raw.githubusercontent.com/codeforgermany/click_that_hood/main/public/data/canada.geojson")
gdf_ca = gdf_ca.rename(columns={"name": "state"})
gdf_ca["state"] = gdf_ca["state"].replace({"Yukon Territory": "Yukon"})	
df_ca = get_data(
    country="Canada",
    year=2021,
    aggregation="state",
    election="federal"
)
data_ca = pd.merge(gdf_ca, df_ca, on="state")
data_ca["country"] = "Canada"

# %%
gdf_mx = gpd.read_file("https://raw.githubusercontent.com/strotgen/mexico-leaflet/master/states.geojson")
gdf_mx = gdf_mx.rename(columns={"state_code": "state_id"})

df_mx = get_data(
    country="Mexico",
    year=2018,
    aggregation="state_id",
    election="first_round"
)
df_mx["state_id"] = df_mx["state_id"].astype(int)

data_mx = pd.merge(gdf_mx, df_mx, on="state_id")
data_mx["country"] = "Mexico"

# %%
gdf_us = gpd.read_file(f"https://raw.githubusercontent.com/PublicaMundi/MappingAPI/master/data/geojson/us-states.json")
gdf_us = gdf_us.rename(columns={"name": "state"})
gdf_us["state"] = gdf_us["state"].str.upper()

df_us = get_data(
    country="United States",
    year=2020,
    aggregation="state",
    election="first_round"
)
data_us = pd.merge(gdf_us, df_us, on="state")
data_us["country"] = "United States"

# %%
## Peru
gdf_pe = gpd.read_file("https://raw.githubusercontent.com/juaneladio/peru-geojson/master/peru_departamental_simple.geojson")
gdf_pe = gdf_pe.rename(columns={"NOMBDEP": "region"})

df_pe = get_data(
    country="Peru",
    year=2021,
    aggregation="region",
    election="first_round"
)

data_pe = pd.merge(gdf_pe, df_pe, on="region")
data_pe["country"] = "Peru"

# %%
## Chile
gdf_cl = gpd.read_file("geo_shapes/Chile/region_id.geojson")
gdf_cl = gdf_cl.rename(columns={"codregion": "region_id"})

df_cl = get_data(
    country="Chile",
    year=2021,
    aggregation="region_id",
    election="first_round"
)
df_cl["region_id"] = df_cl["region_id"].astype(int)

data_cl = pd.merge(gdf_cl, df_cl, on="region_id")
data_cl["country"] = "Chile"

# %%
gdf_ar = gpd.read_file("geo_shapes/Argentina_district.geojson")

gdf_ar = gdf_ar.rename(columns={"nombre": "district"})

df_ar = get_data(
    country="Argentina",
    year=2023,
    aggregation="district",
    election="first_round",
)

data_ar = pd.merge(gdf_ar, df_ar, on="district")
data_ar["country"] = "Argentina"

# %%
gdf_br = gpd.read_file("https://raw.githubusercontent.com/codeforgermany/click_that_hood/main/public/data/brazil-states.geojson")
gdf_br = gdf_br.rename(columns={"sigla": "region_id"})

df_br = get_data(
    country="Brazil",
    year=2022,
    aggregation="region_id",
    election="first_round"
)
data_br = pd.merge(gdf_br, df_br, on="region_id")
data_br["country"] = "Brazil"

# %%
output = []

for item in [
    ("France", [2022], "first_round", "nuts_3"),
    ("Italy", [2022], "first_round", "nuts_2"),
    ("Spain", [2019], "general", "nuts_2"),
    ("Germany", [2021], "general", "nuts_3"),
    ("Belgium", [2019], "general", "nuts_2"),
]:
    country, years, election_round, aggregation = item
    print(country)
    for year in years:
        test = get_data(
            aggregation=aggregation,
            country=country,
            election=election_round,
            year=year 
        )
        test["country"] = country

        for col in ["ec", "ep"]:
            test[f"{col}_n"] = (test[col] - test[col].mean()) / test[col].std()

        output.append(test)

data_eu = pd.concat(output, ignore_index=True)
data_eu.head()
# Out:
# France
# Italy
# Spain
# Germany
# Belgium
#   nuts_3        ec        ep  year country      ec_n      ep_n nuts_2
# 0  FR101  0.837558  0.047447  2022  France -1.448382  1.523533    NaN
# 1  FR102  0.855119  0.040648  2022  France -0.239351  0.547068    NaN
# 2  FR103  0.848425  0.051612  2022  France -0.700214  2.121794    NaN
# 3  FR104  0.855077  0.043838  2022  France -0.242194  1.005195    NaN
# 4  FR105  0.839126  0.048422  2022  France -1.340412  1.663665    NaN

# %%
europe = gpd.read_file("geo_shapes/NUTS_RG_20M_2021_3035.shp.zip").to_crs("epsg:4326")
# gdf_europe = europe[europe["LEVL_CODE"] == 2]
gdf_europe = pd.merge(data_eu, europe[["NUTS_ID", "geometry"]], left_on="nuts_3", right_on="NUTS_ID", how="left")

gdf_europe.head()
# Out:
#   nuts_3        ec        ep  year country      ec_n      ep_n nuts_2 NUTS_ID  \
# 0  FR101  0.837558  0.047447  2022  France -1.448382  1.523533    NaN   FR101
# 1  FR102  0.855119  0.040648  2022  France -0.239351  0.547068    NaN   FR102
# 2  FR103  0.848425  0.051612  2022  France -0.700214  2.121794    NaN   FR103
# 3  FR104  0.855077  0.043838  2022  France -0.242194  1.005195    NaN   FR104
# 4  FR105  0.839126  0.048422  2022  France -1.340412  1.663665    NaN   FR105
#
#                                             geometry
# 0  POLYGON ((2.41634 48.84923, 2.33190 48.81701, ...
# 1  POLYGON ((3.48518 48.85191, 3.43134 48.73927, ...
# 2  POLYGON ((2.20059 48.90868, 2.15938 48.84096, ...
# 3  POLYGON ((1.92215 48.45760, 2.04507 48.67091, ...
# 4  POLYGON ((2.29607 48.87781, 2.27435 48.85073, ...

# %%
nz = gpd.read_file("geo_shapes/New Zealand/region.geojson").to_crs("epsg:4326")
nz = nz.rename(columns={"name": "region"})
nz["region"] = nz["region"].replace({
    "Manawatu-Wanganui": "Manawatū-Whanganui",
    "Gisborne": "Gisborne and Bay of Plenty",
    "Marlborough": "Marlborough and Canterbury",
    "Nelson": "Nelson and Tasman"
})
df_nz = get_data(
    country="New Zealand",
    year=2023,
    aggregation="region",
    election="general"
)

gdf_nz = pd.merge(nz, df_nz, on="region")
gdf_nz["country"] = "New Zealand"
set(nz["region"]) - set(df_nz["region"])
gdf_nz
# Out:
#        id                      region  density  \
# 0   11364                    Auckland        0
# 1   11350               Bay of Plenty        0
# 2   11355                  Canterbury        0
# 3   11351  Gisborne and Bay of Plenty        0
# 4   11352                 Hawke's Bay        0
# 5   11361          Manawatū-Whanganui        0
# 6   11359  Marlborough and Canterbury        0
# 7   11360           Nelson and Tasman        0
# 8   11363                   Northland        0
# 9   11353                       Otago        0
# 10  11354                   Southland        0
# 11  11349                    Taranaki        0
# 12  11356                     Waikato        0
# 13  11362                  Wellington        0
#
#                                     path  \
# 0            /world/New Zealand/Auckland
# 1       /world/New Zealand/Bay of Plenty
# 2          /world/New Zealand/Canterbury
# 3            /world/New Zealand/Gisborne
# 4         /world/New Zealand/Hawke's Bay
# 5   /world/New Zealand/Manawatu-Wanganui
# 6         /world/New Zealand/Marlborough
# 7              /world/New Zealand/Nelson
# 8           /world/New Zealand/Northland
# 9               /world/New Zealand/Otago
# 10          /world/New Zealand/Southland
# 11           /world/New Zealand/Taranaki
# 12            /world/New Zealand/Waikato
# 13         /world/New Zealand/Wellington
#
#                                              geometry        ec        ep  \
# 0   MULTIPOLYGON (((175.90207 -36.25767, 175.89811...  0.000000  1.000000
# 1   MULTIPOLYGON (((178.11969 -37.33577, 178.11513...  0.000000  1.000000
# 2   MULTIPOLYGON (((174.23541 -42.12212, 174.23263...  0.000000  1.000000
# 3   MULTIPOLYGON (((178.83621 -37.68164, 178.83607...  0.773162  0.172500
# 4   MULTIPOLYGON (((178.26302 -39.10981, 178.26291...  0.000000  1.000000
# 5   MULTIPOLYGON (((176.89423 -40.47087, 176.89410...  0.000000  1.000000
# 6   MULTIPOLYGON (((174.59980 -40.89335, 174.59606...  0.635325  0.074830
# 7   MULTIPOLYGON (((173.59876 -41.06965, 173.59870...  0.876440  0.123136
# 8   MULTIPOLYGON (((174.99355 -35.48235, 174.99345...  0.000000  1.000000
# 9   MULTIPOLYGON (((171.41611 -44.99279, 171.41488...  0.000000  1.000000
# 10  MULTIPOLYGON (((169.33718 -46.84107, 169.33229...  0.687442  0.162514
# 11  MULTIPOLYGON (((174.99169 -39.54011, 174.99132...  0.748675  0.123184
# 12  MULTIPOLYGON (((176.50532 -38.40221, 176.49547...  0.000000  1.000000
# 13  MULTIPOLYGON (((176.56149 -40.81355, 176.55836...  0.000000  1.000000
#
#     year      country
# 0   2023  New Zealand
# 1   2023  New Zealand
# 2   2023  New Zealand
# 3   2023  New Zealand
# 4   2023  New Zealand
# 5   2023  New Zealand
# 6   2023  New Zealand
# 7   2023  New Zealand
# 8   2023  New Zealand
# 9   2023  New Zealand
# 10  2023  New Zealand
# 11  2023  New Zealand
# 12  2023  New Zealand
# 13  2023  New Zealand

# %%
set(df_nz["region"]) - set(nz["region"])
# Out:
# {'Manawatū-Whanganui and Taranaki',
#  'Otago and Canterbury',
#  'Southland and Otago',
#  'Taranaki and Waikato',
#  'Wellington and Manawatū-Whanganui',
#  'Wellington and the Chatham Islands',
#  "Wellington, Manawatū-Whanganui and Hawke's Bay",
#  'West Coast and Tasman'}

# %%
world = gpd.read_file("geo_shapes/countries.geojson")
world = world[["NAME_EN", "geometry"]].rename(columns={"NAME_EN": "country"})
world = world[~world["country"].isin(["Chile", "Argentina", "Belgium", "New Zealand", "United States of America", "Brazil", "Mexico", "Canada", "Peru", "France", "Spain", "Italy", "Germany", "Antarctica"])]

# %%
data = pd.concat([data_us, data_mx, data_ca, data_pe, data_cl, data_br, data_ar, gdf_nz, gdf_europe, world])
data = data[data["state"] != "DISTRICT OF COLUMBIA"]
# data = data[~(data["nuts_2"].fillna("#").str.contains("FRY"))]

output = []
for ii, tmp in data.groupby("country"):
    tmp["ep_n"] = (tmp["ep"] - tmp["ep"].mean()) / tmp["ep"].std()
    tmp["ec_n"] = (tmp["ec"] - tmp["ec"].mean()) / tmp["ec"].std()
    output.append(tmp)

data = pd.concat(output, ignore_index=True)
data = gpd.GeoDataFrame(data)

colors = ["#c85200", "#e48646", "#eeb690", "#a6bbc8", "#6b8ea4", "#366785"]
colors.reverse()

def set_colors(x):
    cutoffs = [-1, -0.5, 0, 0.5, 1, 999]
    for i, cutoff in enumerate(cutoffs):
        if x < cutoff:
            return colors[i]

    return "#DBDBDB"
    
data["color_ep"] = data["ep_n"].apply(set_colors)
data["color_ec"] = data["ec_n"].apply(set_colors)
data.head()
# Out:
#     id state  density                                           geometry  ec  \
# 0  NaN   NaN      NaN  POLYGON ((74.54235 37.02167, 74.54742 37.01567... NaN
# 1  NaN   NaN      NaN  POLYGON ((33.01563 34.63442, 33.00994 34.62490... NaN
# 2  NaN   NaN      NaN  POLYGON ((20.56715 41.87318, 20.54172 41.86158... NaN
# 3  NaN   NaN      NaN  POLYGON ((-4.82161 24.99506, -4.99519 25.10209... NaN
# 4  NaN   NaN      NaN  MULTIPOLYGON (((-170.59101 -14.26483, -170.576... NaN
#
#    ep  year         country  state_id state_name  ...  codigo_ibg district  \
# 0 NaN   NaN     Afghanistan       NaN        NaN  ...         NaN      NaN
# 1 NaN   NaN        Akrotiri       NaN        NaN  ...         NaN      NaN
# 2 NaN   NaN         Albania       NaN        NaN  ...         NaN      NaN
# 3 NaN   NaN         Algeria       NaN        NaN  ...         NaN      NaN
# 4 NaN   NaN  American Samoa       NaN        NaN  ...         NaN      NaN
#
#   path nuts_3  ec_n ep_n  nuts_2  NUTS_ID  color_ep  color_ec
# 0  NaN    NaN   NaN  NaN     NaN      NaN   #DBDBDB   #DBDBDB
# 1  NaN    NaN   NaN  NaN     NaN      NaN   #DBDBDB   #DBDBDB
# 2  NaN    NaN   NaN  NaN     NaN      NaN   #DBDBDB   #DBDBDB
# 3  NaN    NaN   NaN  NaN     NaN      NaN   #DBDBDB   #DBDBDB
# 4  NaN    NaN   NaN  NaN     NaN      NaN   #DBDBDB   #DBDBDB
#
# [5 rows x 37 columns]

# %%
data = gdf_europe.dropna(subset=["geometry"])
data = gpd.GeoDataFrame(data, geometry='geometry')

data['centroid'] = data['geometry'].centroid
data['longitude'] = data['centroid'].x
data['latitude'] = data['centroid'].y

data[["ep", "latitude", "longitude"]].dropna().to_json("data2.json", orient="records")
data.head()
# Out:
# C:\Users\cnava\AppData\Local\Temp\ipykernel_36480\23589768.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   data['centroid'] = data['geometry'].centroid
#   nuts_3        ec        ep  year country      ec_n      ep_n nuts_2 NUTS_ID  \
# 0  FR101  0.837558  0.047447  2022  France -1.448382  1.523533    NaN   FR101
# 1  FR102  0.855119  0.040648  2022  France -0.239351  0.547068    NaN   FR102
# 2  FR103  0.848425  0.051612  2022  France -0.700214  2.121794    NaN   FR103
# 3  FR104  0.855077  0.043838  2022  France -0.242194  1.005195    NaN   FR104
# 4  FR105  0.839126  0.048422  2022  France -1.340412  1.663665    NaN   FR105
#
#                                             geometry  \
# 0  POLYGON ((2.41634 48.84923, 2.33190 48.81701, ...
# 1  POLYGON ((3.48518 48.85191, 3.43134 48.73927, ...
# 2  POLYGON ((2.20059 48.90868, 2.15938 48.84096, ...
# 3  POLYGON ((1.92215 48.45760, 2.04507 48.67091, ...
# 4  POLYGON ((2.29607 48.87781, 2.27435 48.85073, ...
#
#                    centroid  longitude   latitude
# 0  POINT (2.33792 48.85602)   2.337918  48.856017
# 1  POINT (2.94605 48.63721)   2.946051  48.637206
# 2  POINT (1.84036 48.81229)   1.840358  48.812288
# 3  POINT (2.24576 48.52053)   2.245756  48.520534
# 4  POINT (2.25089 48.84338)   2.250890  48.843375

# %%
# data[data["country"] == "United States"]

# %%
fig, ax = plt.subplots(dpi=400)
norm = plt.Normalize(-2, 2)

cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", colors)

data[data["country"].isin(["France", "Germany"])].plot(
    column="ep_n",
    # color=data["color_ec"],
    # legend=False,
    legend=True,
    edgecolor="#FFF",
    legend_kwds={
        "location":"bottom",
        "shrink":.25
    },
    cmap=cmap,
    # norm=norm,
    vmin=-2, vmax=2, 
    linewidth=0.2,
    missing_kwds=dict(color="#DBDBDB", label='No Data'),
    ax=ax
)
ax.set_xlim(-10, 20)
ax.set_ylim(40, 55)
ax.axis("off")
fig.tight_layout()

# %%
data_eu.to_csv("polarization-eu.csv", index=False)

# %%
# data_us

# %%
dd = pd.read_csv("regions.csv", encoding="latin-1")
dd = pd.merge(data_eu, dd, left_on="nuts_2", right_on="DT")
list(dd)
# Out:
# ['nuts_2',
#  'ec',
#  'ep',
#  'year',
#  'country',
#  'ec_n',
#  'ep_n',
#  'DT',
#  'NAME',
#  'emplevel',
#  'emplevel2',
#  'empgrowth',
#  'wagelevel',
#  'wagelevel2',
#  'wagegrowth',
#  'gdplevel',
#  'gdplevel2',
#  'gdpgrowth',
#  'prodlevel',
#  'prodlevel2',
#  'prodgrowth',
#  'Average.DT1',
#  'Average.DT2',
#  'GERD_PCT_GDP',
#  'GVA_IND_SHARE',
#  'SHARE_HIGH_EDUC',
#  'EQI',
#  'ardecoemp',
#  'CATG_label',
#  'GeoGroup']

# %%
import seaborn as sns
sns.lmplot(x="gdplevel", hue="country", y="ep", data=dd[dd["country"] == "France"])

# %%
data.to_file('world.geojson', driver='GeoJSON')

# %%
data2 = data[data["country"].isin(["France", "Germany", "Spain", "Italy", "Belgium"])]
fig, ax = plt.subplots(dpi=400)
norm = plt.Normalize(-2, 2)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", colors)

data2.plot(
    color=data2["color_ec"],
    legend=False,
    edgecolor="#FFFFFF",
    legend_kwds={
        # "location":"bottom",
        "shrink":.25
    },
    # vcenter=0,
    linewidth=0.3,
    missing_kwds=dict(color='#DBDBDB', label='No Data'),
    ax=ax
)

ax.set_xlim(-10, 20)
ax.set_ylim(35, 57.5)

ax.axis("off")
fig.tight_layout()
